# %%
import pandas as pd

DATASET='splc21-data - curl-2-200.csv'
SYSTEM_NAME='curl'

odf = pd.read_csv(DATASET)
odf.head()
# Out:
#    --with-aix-soname=aix  --with-aix-soname=svr4  --with-aix-soname=both  \
# 0                  False                   False                   False
# 1                  False                   False                   False
# 2                  False                   False                   False
# 3                  False                   False                   False
# 4                  False                   False                   False
#
#    --with-gnu-ld  --with-zlib  --with-brotli  --with-zstd  --with-ldap-lib  \
# 0          False        False          False        False            False
# 1          False        False          False        False            False
# 2          False        False          False        False            False
# 3          False        False          False        False            False
# 4          False        False          False        False            False
#
#    --with-lber-lib  --with-default-ssl-backend=openssl  ...  \
# 0            False                               False  ...
# 1            False                               False  ...
# 2            False                               False  ...
# 3            False                               False  ...
# 4            False                               False  ...
#
#    --enable-dateparse  --enable-netrc  --enable-progress-meter  \
# 0               False           False                    False
# 1               False           False                    False
# 2               False           False                    False
# 3               False           False                    False
# 4               False           False                    False
#
#    --enable-dnsshuffle  --enable-get-easy-options  --enable-alt-svc  \
# 0                False                      False             False
# 1                False                      False             False
# 2                False                      False             False
# 3                False                      False             False
# 4                False                      False             False
#
#    --enable-hsts  binary-size   unit  nr-of-gadgets
# 0          False       694792  bytes        17503.0
# 1          False       702520  bytes        17963.0
# 2          False       720792  bytes        17604.0
# 3          False       689680  bytes        17144.0
# 4          False       695216  bytes        17618.0
#
# [5 rows x 160 columns]

# %%
odf.columns
# Out:
# Index(['--with-aix-soname=aix', '--with-aix-soname=svr4',
#        '--with-aix-soname=both', '--with-gnu-ld', '--with-zlib',
#        '--with-brotli', '--with-zstd', '--with-ldap-lib', '--with-lber-lib',
#        '--with-default-ssl-backend=openssl',
#        ...
#        '--enable-dateparse', '--enable-netrc', '--enable-progress-meter',
#        '--enable-dnsshuffle', '--enable-get-easy-options', '--enable-alt-svc',
#        '--enable-hsts', 'binary-size', 'unit', 'nr-of-gadgets'],
#       dtype='object', length=160)

# %%
# features to consider
fts = list(odf.columns.values)
fts.remove('nr-of-gadgets')
fts.remove('binary-size')
fts.remove('unit')
fts
# Out:
# ['--with-aix-soname=aix',
#  '--with-aix-soname=svr4',
#  '--with-aix-soname=both',
#  '--with-gnu-ld',
#  '--with-zlib',
#  '--with-brotli',
#  '--with-zstd',
#  '--with-ldap-lib',
#  '--with-lber-lib',
#  '--with-default-ssl-backend=openssl',
#  '--with-ssl',
#  '--with-random',
#  '--with-gnutls',
#  '--with-mbedtls',
#  '--with-nss',
#  '--with-ca-fallback',
#  '--with-libmetalink',
#  '--with-libssh2',
#  '--with-libssh',
#  '--with-librtmp',
#  '--with-libidn2',
#  '--with-nghttp2',
#  '--with-zsh-functions-dir',
#  '--with-fish-functions-dir',
#  '--with-gssapi-includes',
#  '--with-gssapi-libs',
#  '--with-gssapi',
#  '--without-zlib',
#  '--without-brotli',
#  '--without-zstd',
#  '--without-default-ssl-backend',
#  '--without-ssl',
#  '--without-gnutls',
#  '--without-mbedtls',
#  '--without-nss',
#  '--without-ca-bundle',
#  '--without-ca-path',
#  '--without-ca-fallback',
#  '--without-libpsl',
#  '--without-libgsasl',
#  '--without-libmetalink',
#  '--without-librtmp',
#  '--without-winidn',
#  '--without-libidn2',
#  '--without-nghttp2',
#  '--without-zsh-functions-dir',
#  '--without-fish-functions-dir',
#  '--disable-silent-rules',
#  '--disable-debug',
#  '--disable-optimize',
#  '--disable-warnings',
#  '--disable-werror',
#  '--disable-curldebug',
#  '--disable-symbol-hiding',
#  '--disable-hidden-symbols',
#  '--disable-ares',
#  '--disable-rt',
#  '--disable-ech',
#  '--disable-dependency-tracking',
#  '--disable-largefile',
#  '--disable-libtool-lock',
#  '--disable-http',
#  '--disable-ftp',
#  '--disable-file',
#  '--disable-ldap',
#  '--disable-ldaps',
#  '--disable-rtsp',
#  '--disable-proxy',
#  '--disable-dict',
#  '--disable-telnet',
#  '--disable-tftp',
#  '--disable-pop3',
#  '--disable-imap',
#  '--disable-smb',
#  '--disable-smtp',
#  '--disable-gopher',
#  '--disable-mqtt',
#  '--disable-manual',
#  '--disable-libcurl-option',
#  '--disable-ipv6',
#  '--disable-openssl-auto-load-config',
#  '--disable-versioned-symbols',
#  '--disable-threaded-resolver',
#  '--disable-pthreads',
#  '--disable-verbose',
#  '--disable-sspi',
#  '--disable-ntlm-wb',
#  '--disable-tls-srp',
#  '--disable-unix-sockets',
#  '--disable-cookies',
#  '--disable-socketpair',
#  '--disable-http-auth',
#  '--disable-doh',
#  '--disable-mime',
#  '--disable-dateparse',
#  '--disable-netrc',
#  '--disable-progress-meter',
#  '--disable-dnsshuffle',
#  '--disable-get-easy-options',
#  '--disable-alt-svc',
#  '--disable-hsts',
#  '--enable-maintainer-mode',
#  '--enable-silent-rules',
#  '--enable-debug',
#  '--enable-optimize',
#  '--enable-warnings',
#  '--enable-curldebug',
#  '--enable-symbol-hiding',
#  '--enable-hidden-symbols',
#  '--enable-ares',
#  '--enable-ech',
#  '--enable-code-coverage',
#  '--enable-dependency-tracking',
#  '--enable-shared',
#  '--enable-static',
#  '--enable-fast-install-http',
#  '--enable-ftp',
#  '--enable-file',
#  '--enable-ldap',
#  '--enable-ldaps',
#  '--enable-rtsp',
#  '--enable-proxy',
#  '--enable-dict',
#  '--enable-telnet',
#  '--enable-tftp',
#  '--enable-pop3',
#  '--enable-imap',
#  '--enable-smb',
#  '--enable-smtp',
#  '--enable-gopher',
#  '--enable-mqtt',
#  '--enable-manual',
#  '--enable-libcurl-option',
#  '--enable-libgcc',
#  '--enable-ipv6',
#  '--enable-openssl-auto-load-config',
#  '--enable-versioned-symbols',
#  '--enable-threaded-resolver',
#  '--enable-pthreads',
#  '--enable-verbose',
#  '--enable-sspi',
#  '--enable-crypto-auth',
#  '--enable-ntlm-wb',
#  '--enable-tls-srp',
#  '--enable-unix-sockets',
#  '--enable-cookies',
#  '--enable-socketpair',
#  '--enable-http-auth',
#  '--enable-doh',
#  '--enable-mime',
#  '--enable-dateparse',
#  '--enable-netrc',
#  '--enable-progress-meter',
#  '--enable-dnsshuffle',
#  '--enable-get-easy-options',
#  '--enable-alt-svc',
#  '--enable-hsts']

# %%
odf['binary-size'].plot(kind='box')

# %%
odf['binary-size'].plot(kind='hist')

# %%
odf['nr-of-gadgets'].plot(kind='box')

# %%
odf['nr-of-gadgets'].plot(kind='hist')

# %%
from sklearn.model_selection import train_test_split
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
import graphviz 

def mean_absolute_percentage_error(y_pred, y_true):
    return np.average(np.abs(y_pred - y_true) / np.abs(y_true))

def eval_model(target, y_pred, X_test, y_test): 
    print(np.max(y_pred))
    print('Mean squared error: %.2f'
          % mean_squared_error(y_test, y_pred))
    # The coefficient of determination: 1 is perfect prediction
    print('Coefficient of determination: %.2f'
          % r2_score(y_test, y_pred))
    

    
    print("MAPE", mean_absolute_percentage_error(y_pred, y_test))

    # Plot outputs
    plt.scatter(X_test.index, y_test,  color='black')
    plt.plot(X_test.index, y_pred, color='blue', linewidth=3)

    plt.xticks(())
    plt.yticks(())

    plt.show()

def mk_linear_regression(target, test_size=0.8):
    regr = linear_model.LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(odf[fts], odf[target], test_size=test_size, random_state=42)
    regr.fit(X_train, y_train)
    print(regr.coef_)
    coeffs = pd.DataFrame(regr.coef_, fts, columns=['Coefficients'])
    print(coeffs.sort_values(by="Coefficients"))
    coeffs.plot(kind='barh', figsize=(9, 7))
    plt.axvline(x=0, color='.5')
    plt.subplots_adjust(left=.3)
    plt.show()
    
    y_pred = regr.predict(X_test)
    eval_model(target, y_pred, X_test, y_test)
    



def mk_treepredictor(target, decision_tree, test_size=0.8): 
    if decision_tree:
        clf = tree.DecisionTreeRegressor()
    else:
        clf = RandomForestRegressor() 
    X_train, X_test, y_train, y_test = train_test_split(odf[fts], odf[target], test_size=test_size, random_state=42)
   
    clf = clf.fit(X_train, y_train)

    if decision_tree:
        dot_data = tree.export_graphviz(clf, out_file=None, feature_names=fts,  
                      filled=True, rounded=True,  
                      special_characters=True)
        graph = graphviz.Source(dot_data) 
        graph.render(SYSTEM_NAME)
                   
    
    y_pred = clf.predict(X_test)
    eval_model(target, y_pred, X_test, y_test)
    
    importance = clf.feature_importances_
    for i, v in enumerate(importance):
        print('Feature: %d, %s, Score: %.5f' % (i, odf.columns[i], v))
    plt.bar([x for x in range(len(importance))], importance)
    plt.show()
    
mk_linear_regression('binary-size')
mk_treepredictor('binary-size', True)
mk_treepredictor('binary-size', False)
# Out:
# [-1.09139364e-11  7.63975549e-11  8.18545232e-12  3.63797881e-12
#   1.81898940e-12 -1.52340363e-11  3.70619091e-11  1.90993887e-11
#  -2.97859515e-11  2.22199566e+03  1.72803993e-11  4.54747351e-12
#  -4.54747351e-12 -8.18545232e-12 -1.02318154e-11 -1.56887836e-11
#  -1.09139364e-11  5.68434189e-12  3.63797881e-12  5.09317033e-11
#   2.22199566e+03  0.00000000e+00  2.22199566e+03 -4.72937245e-11
#   2.98139957e+04  1.27329258e-11  2.98139957e+04  5.02053361e+04
#  -1.57269891e+03 -2.32200434e+03  2.22199566e+03  9.09494702e-12
#  -1.57269891e+03 -1.57269891e+03 -1.57269891e+03  2.22199566e+03
#  -1.57269891e+03 -1.57269891e+03 -1.57269891e+03 -1.57269891e+03
#  -1.57269891e+03 -1.57269891e+03 -1.57269891e+03  1.98199566e+03
#  -1.57269891e+03 -1.57269891e+03  2.22199566e+03 -2.15332137e+02
#  -2.15332137e+02 -2.15332137e+02 -2.15332137e+02 -2.15332137e+02
#  -2.15332137e+02 -2.15332137e+02 -2.15332137e+02 -2.15332137e+02
#  -2.15332137e+02 -2.15332137e+02 -2.15332137e+02  2.22199566e+03
#   2.22199566e+03 -5.04206682e+04 -2.15332137e+02 -2.15332137e+02
#  -3.73800434e+03 -2.15332137e+02 -2.15332137e+02 -2.15332137e+02
#  -2.15332137e+02 -1.48900043e+04 -2.15332137e+02 -6.81800434e+03
#  -2.15332137e+02 -2.15332137e+02 -6.97000434e+03 -2.11400434e+03
#  -2.15332137e+02 -2.15332137e+02 -2.53700043e+04 -1.96200434e+03
#  -2.15332137e+02 -2.15332137e+02 -2.15332137e+02 -2.15332137e+02
#  -2.15332137e+02 -2.15332137e+02 -2.15332137e+02 -2.15332137e+02
#  -1.96200434e+03 -2.15332137e+02 -2.15332137e+02 -2.15332137e+02
#   0.00000000e+00 -6.23400434e+03 -1.57269891e+03 -1.57269891e+03
#  -1.57269891e+03 -1.57269891e+03 -1.57269891e+03 -1.57269891e+03
#  -1.57269891e+03  2.22199566e+03  2.22199566e+03  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  2.22199566e+03  0.00000000e+00  2.22199566e+03
#   0.00000000e+00  2.22199566e+03  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  2.22199566e+03  0.00000000e+00  0.00000000e+00
#   2.22199566e+03  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  2.22199566e+03  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  2.22199566e+03  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  2.22199566e+03  2.22199566e+03
#   0.00000000e+00  2.22199566e+03  0.00000000e+00  0.00000000e+00
#   6.73399566e+03]
#                           Coefficients
# --disable-http           -50420.668241
# --disable-libcurl-option -25370.004344
# --disable-telnet         -14890.004344
# --disable-smtp            -6970.004344
# --disable-pop3            -6818.004344
# ...                                ...
# --enable-pop3              2221.995656
# --enable-hsts              6733.995656
# --with-gssapi-includes    29813.995656
# --with-gssapi             29813.995656
# --without-zlib            50205.336104
#
# [157 rows x 1 columns]
# Mean squared error: 339480774306.33
# Coefficient of determination: 0.02
# 926849.9348380396
# MAPE 0.6827383101527253
# /usr/local/lib64/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/local/lib64/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# Mean squared error: 343926386230.39
# Coefficient of determination: 0.00
# 865928.0
# MAPE 0.6819302270848954
# /usr/local/lib64/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/local/lib64/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# Feature: 0, --with-aix-soname=aix, Score: 0.00000
# Feature: 1, --with-aix-soname=svr4, Score: 0.00000
# Feature: 2, --with-aix-soname=both, Score: 0.00000
# Feature: 3, --with-gnu-ld, Score: 0.00000
# Feature: 4, --with-zlib, Score: 0.00000
# Feature: 5, --with-brotli, Score: 0.00000
# Feature: 6, --with-zstd, Score: 0.00000
# Feature: 7, --with-ldap-lib, Score: 0.00000
# Feature: 8, --with-lber-lib, Score: 0.00000
# Feature: 9, --with-default-ssl-backend=openssl, Score: 0.00000
# Feature: 10, --with-ssl, Score: 0.00000
# Feature: 11, --with-random, Score: 0.00000
# Feature: 12, --with-gnutls, Score: 0.00000
# Feature: 13, --with-mbedtls, Score: 0.00000
# Feature: 14, --with-nss, Score: 0.00000
# Feature: 15, --with-ca-fallback, Score: 0.00000
# Feature: 16, --with-libmetalink, Score: 0.00000
# Feature: 17, --with-libssh2, Score: 0.00000
# Feature: 18, --with-libssh, Score: 0.00000
# Feature: 19, --with-librtmp, Score: 0.00000
# Feature: 20, --with-libidn2, Score: 0.00000
# Feature: 21, --with-nghttp2, Score: 0.00000
# Feature: 22, --with-zsh-functions-dir, Score: 0.00000
# Feature: 23, --with-fish-functions-dir, Score: 0.00000
# Feature: 24, --with-gssapi-includes, Score: 0.01426
# Feature: 25, --with-gssapi-libs, Score: 0.00000
# Feature: 26, --with-gssapi, Score: 0.01521
# Feature: 27, --without-zlib, Score: 0.00000
# Feature: 28, --without-brotli, Score: 0.00000
# Feature: 29, --without-zstd, Score: 0.00029
# Feature: 30, --without-default-ssl-backend, Score: 0.00000
# Feature: 31, --without-ssl, Score: 0.00000
# Feature: 32, --without-gnutls, Score: 0.00000
# Feature: 33, --without-mbedtls, Score: 0.00000
# Feature: 34, --without-nss, Score: 0.00646
# Feature: 35, --without-ca-bundle, Score: 0.00000
# Feature: 36, --without-ca-path, Score: 0.00000
# Feature: 37, --without-ca-fallback, Score: 0.00000
# Feature: 38, --without-libpsl, Score: 0.00000
# Feature: 39, --without-libgsasl, Score: 0.00000
# Feature: 40, --without-libmetalink, Score: 0.00000
# Feature: 41, --without-librtmp, Score: 0.00000
# Feature: 42, --without-winidn, Score: 0.00000
# Feature: 43, --without-libidn2, Score: 0.00000
# Feature: 44, --without-nghttp2, Score: 0.00000
# Feature: 45, --without-zsh-functions-dir, Score: 0.00000
# Feature: 46, --without-fish-functions-dir, Score: 0.00000
# Feature: 47, --disable-silent-rules, Score: 0.00000
# Feature: 48, --disable-debug, Score: 0.00000
# Feature: 49, --disable-optimize, Score: 0.00000
# Feature: 50, --disable-warnings, Score: 0.00000
# Feature: 51, --disable-werror, Score: 0.00000
# Feature: 52, --disable-curldebug, Score: 0.00000
# Feature: 53, --disable-symbol-hiding, Score: 0.00469
# Feature: 54, --disable-hidden-symbols, Score: 0.00000
# Feature: 55, --disable-ares, Score: 0.00000
# Feature: 56, --disable-rt, Score: 0.00000
# Feature: 57, --disable-ech, Score: 0.00000
# Feature: 58, --disable-dependency-tracking, Score: 0.00000
# Feature: 59, --disable-largefile, Score: 0.00000
# Feature: 60, --disable-libtool-lock, Score: 0.00000
# Feature: 61, --disable-http, Score: 0.89884
# Feature: 62, --disable-ftp, Score: 0.00000
# Feature: 63, --disable-file, Score: 0.00000
# Feature: 64, --disable-ldap, Score: 0.00053
# Feature: 65, --disable-ldaps, Score: 0.00000
# Feature: 66, --disable-rtsp, Score: 0.00000
# Feature: 67, --disable-proxy, Score: 0.00000
# Feature: 68, --disable-dict, Score: 0.00000
# Feature: 69, --disable-telnet, Score: 0.00000
# Feature: 70, --disable-tftp, Score: 0.00000
# Feature: 71, --disable-pop3, Score: 0.00116
# Feature: 72, --disable-imap, Score: 0.00000
# Feature: 73, --disable-smb, Score: 0.00000
# Feature: 74, --disable-smtp, Score: 0.00113
# Feature: 75, --disable-gopher, Score: 0.00179
# Feature: 76, --disable-mqtt, Score: 0.00000
# Feature: 77, --disable-manual, Score: 0.00000
# Feature: 78, --disable-libcurl-option, Score: 0.05347
# Feature: 79, --disable-ipv6, Score: 0.00028
# Feature: 80, --disable-openssl-auto-load-config, Score: 0.00000
# Feature: 81, --disable-versioned-symbols, Score: 0.00000
# Feature: 82, --disable-threaded-resolver, Score: 0.00000
# Feature: 83, --disable-pthreads, Score: 0.00000
# Feature: 84, --disable-verbose, Score: 0.00000
# Feature: 85, --disable-sspi, Score: 0.00000
# Feature: 86, --disable-ntlm-wb, Score: 0.00000
# Feature: 87, --disable-tls-srp, Score: 0.00000
# Feature: 88, --disable-unix-sockets, Score: 0.00031
# Feature: 89, --disable-cookies, Score: 0.00000
# Feature: 90, --disable-socketpair, Score: 0.00000
# Feature: 91, --disable-http-auth, Score: 0.00000
# Feature: 92, --disable-doh, Score: 0.00000
# Feature: 93, --disable-mime, Score: 0.00108
# Feature: 94, --disable-dateparse, Score: 0.00000
# Feature: 95, --disable-netrc, Score: 0.00000
# Feature: 96, --disable-progress-meter, Score: 0.00000
# Feature: 97, --disable-dnsshuffle, Score: 0.00000
# Feature: 98, --disable-get-easy-options, Score: 0.00000
# Feature: 99, --disable-alt-svc, Score: 0.00000
# Feature: 100, --disable-hsts, Score: 0.00000
# Feature: 101, --enable-maintainer-mode, Score: 0.00000
# Feature: 102, --enable-silent-rules, Score: 0.00000
# Feature: 103, --enable-debug, Score: 0.00000
# Feature: 104, --enable-optimize, Score: 0.00000
# Feature: 105, --enable-warnings, Score: 0.00000
# Feature: 106, --enable-curldebug, Score: 0.00000
# Feature: 107, --enable-symbol-hiding, Score: 0.00000
# Feature: 108, --enable-hidden-symbols, Score: 0.00000
# Feature: 109, --enable-ares, Score: 0.00000
# Feature: 110, --enable-ech, Score: 0.00000
# Feature: 111, --enable-code-coverage, Score: 0.00000
# Feature: 112, --enable-dependency-tracking, Score: 0.00000
# Feature: 113, --enable-shared, Score: 0.00000
# Feature: 114, --enable-static, Score: 0.00000
# Feature: 115, --enable-fast-install-http, Score: 0.00000
# Feature: 116, --enable-ftp, Score: 0.00000
# Feature: 117, --enable-file, Score: 0.00000
# Feature: 118, --enable-ldap, Score: 0.00000
# Feature: 119, --enable-ldaps, Score: 0.00000
# Feature: 120, --enable-rtsp, Score: 0.00000
# Feature: 121, --enable-proxy, Score: 0.00000
# Feature: 122, --enable-dict, Score: 0.00000
# Feature: 123, --enable-telnet, Score: 0.00000
# Feature: 124, --enable-tftp, Score: 0.00000
# Feature: 125, --enable-pop3, Score: 0.00000
# Feature: 126, --enable-imap, Score: 0.00000
# Feature: 127, --enable-smb, Score: 0.00000
# Feature: 128, --enable-smtp, Score: 0.00000
# Feature: 129, --enable-gopher, Score: 0.00000
# Feature: 130, --enable-mqtt, Score: 0.00000
# Feature: 131, --enable-manual, Score: 0.00000
# Feature: 132, --enable-libcurl-option, Score: 0.00000
# Feature: 133, --enable-libgcc, Score: 0.00000
# Feature: 134, --enable-ipv6, Score: 0.00000
# Feature: 135, --enable-openssl-auto-load-config, Score: 0.00000
# Feature: 136, --enable-versioned-symbols, Score: 0.00000
# Feature: 137, --enable-threaded-resolver, Score: 0.00000
# Feature: 138, --enable-pthreads, Score: 0.00000
# Feature: 139, --enable-verbose, Score: 0.00000
# Feature: 140, --enable-sspi, Score: 0.00000
# Feature: 141, --enable-crypto-auth, Score: 0.00000
# Feature: 142, --enable-ntlm-wb, Score: 0.00000
# Feature: 143, --enable-tls-srp, Score: 0.00000
# Feature: 144, --enable-unix-sockets, Score: 0.00000
# Feature: 145, --enable-cookies, Score: 0.00000
# Feature: 146, --enable-socketpair, Score: 0.00000
# Feature: 147, --enable-http-auth, Score: 0.00000
# Feature: 148, --enable-doh, Score: 0.00000
# Feature: 149, --enable-mime, Score: 0.00000
# Feature: 150, --enable-dateparse, Score: 0.00000
# Feature: 151, --enable-netrc, Score: 0.00000
# Feature: 152, --enable-progress-meter, Score: 0.00000
# Feature: 153, --enable-dnsshuffle, Score: 0.00000
# Feature: 154, --enable-get-easy-options, Score: 0.00000
# Feature: 155, --enable-alt-svc, Score: 0.00000
# Feature: 156, --enable-hsts, Score: 0.00048
# Mean squared error: 344164298081.20
# Coefficient of determination: 0.00
# 862341.04
# MAPE 0.6823656524008714
# /usr/local/lib64/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/local/lib64/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# Feature: 0, --with-aix-soname=aix, Score: 0.00000
# Feature: 1, --with-aix-soname=svr4, Score: 0.00000
# Feature: 2, --with-aix-soname=both, Score: 0.00000
# Feature: 3, --with-gnu-ld, Score: 0.00000
# Feature: 4, --with-zlib, Score: 0.00000
# Feature: 5, --with-brotli, Score: 0.00000
# Feature: 6, --with-zstd, Score: 0.00000
# Feature: 7, --with-ldap-lib, Score: 0.00000
# Feature: 8, --with-lber-lib, Score: 0.00000
# Feature: 9, --with-default-ssl-backend=openssl, Score: 0.00000
# Feature: 10, --with-ssl, Score: 0.00000
# Feature: 11, --with-random, Score: 0.00000
# Feature: 12, --with-gnutls, Score: 0.00000
# Feature: 13, --with-mbedtls, Score: 0.00000
# Feature: 14, --with-nss, Score: 0.00000
# Feature: 15, --with-ca-fallback, Score: 0.00000
# Feature: 16, --with-libmetalink, Score: 0.00000
# Feature: 17, --with-libssh2, Score: 0.00000
# Feature: 18, --with-libssh, Score: 0.00000
# Feature: 19, --with-librtmp, Score: 0.00000
# Feature: 20, --with-libidn2, Score: 0.00000
# Feature: 21, --with-nghttp2, Score: 0.00000
# Feature: 22, --with-zsh-functions-dir, Score: 0.00000
# Feature: 23, --with-fish-functions-dir, Score: 0.00000
# Feature: 24, --with-gssapi-includes, Score: 0.03552
# Feature: 25, --with-gssapi-libs, Score: 0.00000
# Feature: 26, --with-gssapi, Score: 0.04168
# Feature: 27, --without-zlib, Score: 0.00011
# Feature: 28, --without-brotli, Score: 0.00088
# Feature: 29, --without-zstd, Score: 0.00092
# Feature: 30, --without-default-ssl-backend, Score: 0.00018
# Feature: 31, --without-ssl, Score: 0.00000
# Feature: 32, --without-gnutls, Score: 0.00721
# Feature: 33, --without-mbedtls, Score: 0.00006
# Feature: 34, --without-nss, Score: 0.00028
# Feature: 35, --without-ca-bundle, Score: 0.01029
# Feature: 36, --without-ca-path, Score: 0.00006
# Feature: 37, --without-ca-fallback, Score: 0.00015
# Feature: 38, --without-libpsl, Score: 0.00115
# Feature: 39, --without-libgsasl, Score: 0.00034
# Feature: 40, --without-libmetalink, Score: 0.00142
# Feature: 41, --without-librtmp, Score: 0.00324
# Feature: 42, --without-winidn, Score: 0.00011
# Feature: 43, --without-libidn2, Score: 0.00067
# Feature: 44, --without-nghttp2, Score: 0.00014
# Feature: 45, --without-zsh-functions-dir, Score: 0.00115
# Feature: 46, --without-fish-functions-dir, Score: 0.00005
# Feature: 47, --disable-silent-rules, Score: 0.00000
# Feature: 48, --disable-debug, Score: 0.00986
# Feature: 49, --disable-optimize, Score: 0.00985
# Feature: 50, --disable-warnings, Score: 0.00964
# Feature: 51, --disable-werror, Score: 0.01088
# Feature: 52, --disable-curldebug, Score: 0.00963
# Feature: 53, --disable-symbol-hiding, Score: 0.00996
# Feature: 54, --disable-hidden-symbols, Score: 0.01003
# Feature: 55, --disable-ares, Score: 0.00954
# Feature: 56, --disable-rt, Score: 0.01377
# Feature: 57, --disable-ech, Score: 0.00000
# Feature: 58, --disable-dependency-tracking, Score: 0.01829
# Feature: 59, --disable-largefile, Score: 0.00000
# Feature: 60, --disable-libtool-lock, Score: 0.00000
# Feature: 61, --disable-http, Score: 0.48525
# Feature: 62, --disable-ftp, Score: 0.00917
# Feature: 63, --disable-file, Score: 0.00932
# Feature: 64, --disable-ldap, Score: 0.00135
# Feature: 65, --disable-ldaps, Score: 0.00000
# Feature: 66, --disable-rtsp, Score: 0.01163
# Feature: 67, --disable-proxy, Score: 0.00936
# Feature: 68, --disable-dict, Score: 0.00670
# Feature: 69, --disable-telnet, Score: 0.00320
# Feature: 70, --disable-tftp, Score: 0.01622
# Feature: 71, --disable-pop3, Score: 0.00311
# Feature: 72, --disable-imap, Score: 0.00000
# Feature: 73, --disable-smb, Score: 0.02805
# Feature: 74, --disable-smtp, Score: 0.00484
# Feature: 75, --disable-gopher, Score: 0.00109
# Feature: 76, --disable-mqtt, Score: 0.01804
# Feature: 77, --disable-manual, Score: 0.00000
# Feature: 78, --disable-libcurl-option, Score: 0.06974
# Feature: 79, --disable-ipv6, Score: 0.00193
# Feature: 80, --disable-openssl-auto-load-config, Score: 0.00934
# Feature: 81, --disable-versioned-symbols, Score: 0.00878
# Feature: 82, --disable-threaded-resolver, Score: 0.02708
# Feature: 83, --disable-pthreads, Score: 0.00977
# Feature: 84, --disable-verbose, Score: 0.00007
# Feature: 85, --disable-sspi, Score: 0.00006
# Feature: 86, --disable-ntlm-wb, Score: 0.00935
# Feature: 87, --disable-tls-srp, Score: 0.00007
# Feature: 88, --disable-unix-sockets, Score: 0.00075
# Feature: 89, --disable-cookies, Score: 0.02800
# Feature: 90, --disable-socketpair, Score: 0.00112
# Feature: 91, --disable-http-auth, Score: 0.00000
# Feature: 92, --disable-doh, Score: 0.00000
# Feature: 93, --disable-mime, Score: 0.00440
# Feature: 94, --disable-dateparse, Score: 0.00017
# Feature: 95, --disable-netrc, Score: 0.00067
# Feature: 96, --disable-progress-meter, Score: 0.00037
# Feature: 97, --disable-dnsshuffle, Score: 0.00005
# Feature: 98, --disable-get-easy-options, Score: 0.00087
# Feature: 99, --disable-alt-svc, Score: 0.00151
# Feature: 100, --disable-hsts, Score: 0.00067
# Feature: 101, --enable-maintainer-mode, Score: 0.00000
# Feature: 102, --enable-silent-rules, Score: 0.00000
# Feature: 103, --enable-debug, Score: 0.00000
# Feature: 104, --enable-optimize, Score: 0.00000
# Feature: 105, --enable-warnings, Score: 0.00000
# Feature: 106, --enable-curldebug, Score: 0.00000
# Feature: 107, --enable-symbol-hiding, Score: 0.00000
# Feature: 108, --enable-hidden-symbols, Score: 0.00000
# Feature: 109, --enable-ares, Score: 0.00000
# Feature: 110, --enable-ech, Score: 0.00000
# Feature: 111, --enable-code-coverage, Score: 0.00000
# Feature: 112, --enable-dependency-tracking, Score: 0.00000
# Feature: 113, --enable-shared, Score: 0.00000
# Feature: 114, --enable-static, Score: 0.00000
# Feature: 115, --enable-fast-install-http, Score: 0.00000
# Feature: 116, --enable-ftp, Score: 0.00000
# Feature: 117, --enable-file, Score: 0.00000
# Feature: 118, --enable-ldap, Score: 0.00000
# Feature: 119, --enable-ldaps, Score: 0.00000
# Feature: 120, --enable-rtsp, Score: 0.00000
# Feature: 121, --enable-proxy, Score: 0.00000
# Feature: 122, --enable-dict, Score: 0.00000
# Feature: 123, --enable-telnet, Score: 0.00000
# Feature: 124, --enable-tftp, Score: 0.00000
# Feature: 125, --enable-pop3, Score: 0.00000
# Feature: 126, --enable-imap, Score: 0.00000
# Feature: 127, --enable-smb, Score: 0.00000
# Feature: 128, --enable-smtp, Score: 0.00000
# Feature: 129, --enable-gopher, Score: 0.00000
# Feature: 130, --enable-mqtt, Score: 0.00000
# Feature: 131, --enable-manual, Score: 0.00000
# Feature: 132, --enable-libcurl-option, Score: 0.00000
# Feature: 133, --enable-libgcc, Score: 0.00000
# Feature: 134, --enable-ipv6, Score: 0.00000
# Feature: 135, --enable-openssl-auto-load-config, Score: 0.00000
# Feature: 136, --enable-versioned-symbols, Score: 0.00000
# Feature: 137, --enable-threaded-resolver, Score: 0.00000
# Feature: 138, --enable-pthreads, Score: 0.00000
# Feature: 139, --enable-verbose, Score: 0.00000
# Feature: 140, --enable-sspi, Score: 0.00000
# Feature: 141, --enable-crypto-auth, Score: 0.00000
# Feature: 142, --enable-ntlm-wb, Score: 0.00000
# Feature: 143, --enable-tls-srp, Score: 0.00000
# Feature: 144, --enable-unix-sockets, Score: 0.00000
# Feature: 145, --enable-cookies, Score: 0.00000
# Feature: 146, --enable-socketpair, Score: 0.00000
# Feature: 147, --enable-http-auth, Score: 0.00000
# Feature: 148, --enable-doh, Score: 0.00000
# Feature: 149, --enable-mime, Score: 0.00000
# Feature: 150, --enable-dateparse, Score: 0.00000
# Feature: 151, --enable-netrc, Score: 0.00000
# Feature: 152, --enable-progress-meter, Score: 0.00000
# Feature: 153, --enable-dnsshuffle, Score: 0.00000
# Feature: 154, --enable-get-easy-options, Score: 0.00000
# Feature: 155, --enable-alt-svc, Score: 0.00000
# Feature: 156, --enable-hsts, Score: 0.00087

# %%
# mk_linear_regression('nr-of-gadgets')
# mk_treepredictor('nr-of-gadgets', True)
mk_treepredictor('nr-of-gadgets', False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b94882ff99ee> in <module>
#       1 # mk_linear_regression('nr-of-gadgets')
#       2 # mk_treepredictor('nr-of-gadgets', True)
# ----> 3 mk_treepredictor('nr-of-gadgets', False)
#
# <ipython-input-12-c70a17180ffa> in mk_treepredictor(target, decision_tree, test_size)
#      70
#      71     y_pred = clf.predict(X_test)
# ---> 72     eval_model(target, y_pred, X_test, y_test)
#      73
#      74     importance = clf.feature_importances_
#
# <ipython-input-12-c70a17180ffa> in eval_model(target, y_pred, X_test, y_test)
#      16 def eval_model(target, y_pred, X_test, y_test):
#      17     print('Mean squared error: %.2f'
# ---> 18           % mean_squared_error(y_test, y_pred))
#      19     # The coefficient of determination: 1 is perfect prediction
#      20     print('Coefficient of determination: %.2f'
#
# /usr/local/lib64/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib64/python3.7/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     252     """
#     253     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 254         y_true, y_pred, multioutput)
#     255     check_consistent_length(y_true, y_pred, sample_weight)
#     256     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# /usr/local/lib64/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      83     """
#      84     check_consistent_length(y_true, y_pred)
# ---> 85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      87
#
# /usr/local/lib64/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib64/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     644         if force_all_finite:
#     645             _assert_all_finite(array,
# --> 646                                allow_nan=force_all_finite == 'allow-nan')
#     647
#     648     if ensure_min_samples > 0:
#
# /usr/local/lib64/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      98                     msg_err.format
#      99                     (type_err,
# --> 100                      msg_dtype if msg_dtype is not None else X.dtype)
#     101             )
#     102     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
odf['binary-size'].corr(odf['nr-of-gadgets'])
# Out:
# 0.9980313187017958
