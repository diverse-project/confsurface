# %%
import pandas as pd

DATASET='splc21-data - NodeJS - Binary sizes.csv'
SYSTEM_NAME='nodejs'

odf = pd.read_csv(DATASET)
odf = odf.drop(odf.columns[0], axis=1)
odf = odf.rename(columns={'size' : 'binary-size'})
odf.head()
# Out:
#    --cross-compiling  --fully-static  --enable-lto  --openssl-no-asm  \
# 0               True           False         False              True
# 1               True           False         False             False
# 2               True           False         False              True
# 3               True           False         False              True
# 4              False            True         False              True
#
#    --openssl-is-fips  --experimental-enable-pointer-compression  \
# 0              False                                       True
# 1               True                                      False
# 2              False                                      False
# 3              False                                      False
# 4               True                                      False
#
#    --without-intl  --without-node-snapshot  --without-node-code-cache  \
# 0           False                    False                       True
# 1            True                     True                      False
# 2           False                    False                      False
# 3            True                     True                       True
# 4            True                    False                      False
#
#    --enable-static  --v8-lite-mode  binary-size   unit
# 0            False           False     76102128  bytes
# 1            False            True     41191720  bytes
# 2            False           False     73987328  bytes
# 3             True           False     38771224  bytes
# 4            False            True     38771224  bytes

# %%
odf.columns
# Out:
# Index(['--cross-compiling', '--fully-static', '--enable-lto',
#        '--openssl-no-asm', '--openssl-is-fips',
#        '--experimental-enable-pointer-compression', '--without-intl',
#        '--without-node-snapshot', '--without-node-code-cache',
#        '--enable-static', '--v8-lite-mode', 'binary-size', 'unit'],
#       dtype='object')

# %%
# features to consider
fts = list(odf.columns.values)
# fts.remove('nr-of-gadgets')
fts.remove('binary-size')
fts.remove('unit')
fts
# Out:
# ['--cross-compiling',
#  '--fully-static',
#  '--enable-lto',
#  '--openssl-no-asm',
#  '--openssl-is-fips',
#  '--experimental-enable-pointer-compression',
#  '--without-intl',
#  '--without-node-snapshot',
#  '--without-node-code-cache',
#  '--enable-static',
#  '--v8-lite-mode']

# %%
odf['binary-size'].plot(kind='box')

# %%
odf['binary-size'].plot(kind='hist')

# %%
# odf['nr-of-gadgets'].plot(kind='box')

# %%
# odf['nr-of-gadgets'].plot(kind='hist')

# %%
from sklearn.model_selection import train_test_split
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
import graphviz 

def mean_absolute_percentage_error(y_pred, y_true):
    return np.average(np.abs(y_pred - y_true) / np.abs(y_true))

def eval_model(target, y_pred, X_test, y_test): 
    print('Mean squared error: %.2f'
          % mean_squared_error(y_test, y_pred))
    # The coefficient of determination: 1 is perfect prediction
    print('Coefficient of determination: %.2f'
          % r2_score(y_test, y_pred))
    
    print("MAPE", mean_absolute_percentage_error(y_pred, y_test))

    # Plot outputs
    plt.scatter(X_test.index, y_test,  color='black')
    plt.plot(X_test.index, y_pred, color='blue', linewidth=3)

    plt.xticks(())
    plt.yticks(())

    plt.show()

def mk_linear_regression(target, test_size=0.8):
    regr = linear_model.LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(odf[fts], odf[target], test_size=test_size, random_state=42)
    regr.fit(X_train, y_train)
    print(regr.coef_)
    coeffs = pd.DataFrame(regr.coef_, fts, columns=['Coefficients'])
    print(coeffs.sort_values(by="Coefficients"))
    coeffs.plot(kind='barh', figsize=(9, 7))
    plt.axvline(x=0, color='.5')
    plt.subplots_adjust(left=.3)
    plt.show()
    
    y_pred = regr.predict(X_test)
    eval_model(target, y_pred, X_test, y_test)
    



def mk_treepredictor(target, decision_tree, test_size=0.8): 
    if decision_tree:
        clf = tree.DecisionTreeRegressor()
    else:
        clf = RandomForestRegressor() 
    X_train, X_test, y_train, y_test = train_test_split(odf[fts], odf[target], test_size=test_size, random_state=42)
   
    clf = clf.fit(X_train, y_train)

    if decision_tree:
        dot_data = tree.export_graphviz(clf, out_file=None, feature_names=fts,  
                      filled=True, rounded=True,  
                      special_characters=True)
        graph = graphviz.Source(dot_data) 
        graph.render(SYSTEM_NAME)
                   
    
    y_pred = clf.predict(X_test)
    eval_model(target, y_pred, X_test, y_test)
    
    importance = clf.feature_importances_
    for i, v in enumerate(importance):
        print('Feature: %d, %s, Score: %.5f' % (i, odf.columns[i], v))
    plt.bar([x for x in range(len(importance))], importance)
    plt.show()
    
mk_linear_regression('binary-size')
mk_treepredictor('binary-size', True)
mk_treepredictor('binary-size', False)
# Out:
# [ 1.27033852e+07  8.95214529e+06  8.07816518e+07  2.17088895e+08
#   3.07548497e+07 -7.04479545e+07  1.13870539e+08 -1.02423292e+08
#   5.62663693e+07 -2.61398054e+07  2.07543946e+07]
#                                            Coefficients
# --without-node-snapshot                   -1.024233e+08
# --experimental-enable-pointer-compression -7.044795e+07
# --enable-static                           -2.613981e+07
# --fully-static                             8.952145e+06
# --cross-compiling                          1.270339e+07
# --v8-lite-mode                             2.075439e+07
# --openssl-is-fips                          3.075485e+07
# --without-node-code-cache                  5.626637e+07
# --enable-lto                               8.078165e+07
# --without-intl                             1.138705e+08
# --openssl-no-asm                           2.170889e+08
# Mean squared error: 23895645130741600.00
# Coefficient of determination: -17.70
# MAPE 1.7676414678902688
# Mean squared error: 1529670279480267.25
# Coefficient of determination: -0.20
# MAPE 0.426111054640784
# Feature: 0, --cross-compiling, Score: 0.00000
# Feature: 1, --fully-static, Score: 0.21959
# Feature: 2, --enable-lto, Score: 0.09085
# Feature: 3, --openssl-no-asm, Score: 0.00004
# Feature: 4, --openssl-is-fips, Score: 0.00000
# Feature: 5, --experimental-enable-pointer-compression, Score: 0.08406
# Feature: 6, --without-intl, Score: 0.37888
# Feature: 7, --without-node-snapshot, Score: 0.22657
# Feature: 8, --without-node-code-cache, Score: 0.00000
# Feature: 9, --enable-static, Score: 0.00000
# Feature: 10, --v8-lite-mode, Score: 0.00000
# Mean squared error: 1154334815517459.50
# Coefficient of determination: 0.10
# MAPE 0.48384016334696484
# Feature: 0, --cross-compiling, Score: 0.04538
# Feature: 1, --fully-static, Score: 0.13678
# Feature: 2, --enable-lto, Score: 0.10385
# Feature: 3, --openssl-no-asm, Score: 0.16562
# Feature: 4, --openssl-is-fips, Score: 0.03149
# Feature: 5, --experimental-enable-pointer-compression, Score: 0.04482
# Feature: 6, --without-intl, Score: 0.16333
# Feature: 7, --without-node-snapshot, Score: 0.03369
# Feature: 8, --without-node-code-cache, Score: 0.08297
# Feature: 9, --enable-static, Score: 0.16336
# Feature: 10, --v8-lite-mode, Score: 0.02870

# %%
# mk_linear_regression('nr-of-gadgets')
# mk_treepredictor('nr-of-gadgets', True)
# mk_treepredictor('nr-of-gadgets', False)
