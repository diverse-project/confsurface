# %%
import pandas as pd

DATASET='splc21-data - nginx-200.csv'
SYSTEM_NAME='nginx'

odf = pd.read_csv(DATASET)
odf.head()
# Out:
#    --with-select_module  --with-poll_module  --with-threads  --with-file-aio  \
# 0                  True                True            True            False
# 1                  True               False           False            False
# 2                 False               False            True            False
# 3                 False                True            True            False
# 4                 False                True            True             True
#
#    --with-http_ssl_module  --with-http_v2_module  --with-http_realip_module  \
# 0                    True                   True                      False
# 1                    True                  False                       True
# 2                   False                   True                      False
# 3                   False                   True                      False
# 4                   False                  False                       True
#
#    --with-http_addition_module  --with-http_xslt_module  \
# 0                         True                    False
# 1                         True                     True
# 2                        False                     True
# 3                         True                    False
# 4                        False                     True
#
#    --with-http_xslt_module=dynamic  ...  --without-stream_map_module  \
# 0                             True  ...                         True
# 1                             True  ...                        False
# 2                            False  ...                         True
# 3                             True  ...                         True
# 4                             True  ...                        False
#
#    --without-stream_split_clients_module  --without-stream_return_module  \
# 0                                   True                           False
# 1                                   True                            True
# 2                                  False                            True
# 3                                  False                           False
# 4                                   True                           False
#
#    --without-stream_upstream_hash_module  \
# 0                                   True
# 1                                   True
# 2                                   True
# 3                                  False
# 4                                   True
#
#    --without-stream_upstream_least_conn_module  \
# 0                                        False
# 1                                         True
# 2                                        False
# 3                                        False
# 4                                        False
#
#    --without-stream_upstream_random_module  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                     True
#
#    --without-stream_upstream_zone_module  binary-size   unit  nr-of-gadgets
# 0                                  False      2288288  bytes          17886
# 1                                   True      1516952  bytes          12336
# 2                                  False      5655640  bytes          37294
# 3                                  False      1901288  bytes          15095
# 4                                  False      1561560  bytes          12524
#
# [5 rows x 93 columns]

# %%
odf.columns
# Out:
# Index(['--with-select_module', '--with-poll_module', '--with-threads',
#        '--with-file-aio', '--with-http_ssl_module', '--with-http_v2_module',
#        '--with-http_realip_module', '--with-http_addition_module',
#        '--with-http_xslt_module', '--with-http_xslt_module=dynamic',
#        '--with-http_image_filter_module',
#        '--with-http_image_filter_module=dynamic', '--with-http_geoip_module',
#        '--with-http_geoip_module=dynamic', '--with-http_sub_module',
#        '--with-http_dav_module', '--with-http_flv_module',
#        '--with-http_mp4_module', '--with-http_gunzip_module',
#        '--with-http_gzip_static_module', '--with-http_auth_request_module',
#        '--with-http_random_index_module', '--with-http_secure_link_module',
#        '--with-http_degradation_module', '--with-http_slice_module',
#        '--with-http_stub_status_module', '--with-http_perl_module=dynamic',
#        '--with-mail', '--with-mail=dynamic', '--with-mail_ssl_module',
#        '--with-stream', '--with-stream=dynamic', '--with-stream_ssl_module',
#        '--with-stream_realip_module', '--with-stream_geoip_module',
#        '--with-stream_geoip_module=dynamic',
#        '--with-stream_ssl_preread_module', '--with-google_perftools_module',
#        '--with-compat', '--with-pcre', '--with-pcre-jit',
#        '--with-zlib-asm=CPU', '--with-libatomic', '--with-debug',
#        '--without-select_module', '--without-poll_module',
#        '--without-http_charset_module', '--without-http_gzip_module',
#        '--without-http_ssi_module', '--without-http_userid_module',
#        '--without-http_access_module', '--without-http_auth_basic_module',
#        '--without-http_mirror_module', '--without-http_autoindex_module',
#        '--without-http_geo_module', '--without-http_map_module',
#        '--without-http_split_clients_module', '--without-http_referer_module',
#        '--without-http_rewrite_module', '--without-http_proxy_module',
#        '--without-http_fastcgi_module', '--without-http_uwsgi_module',
#        '--without-http_scgi_module', '--without-http_grpc_module',
#        '--without-http_memcached_module', '--without-http_limit_conn_module',
#        '--without-http_limit_req_module', '--without-http_empty_gif_module',
#        '--without-http_browser_module', '--without-http_upstream_hash_module',
#        '--without-http_upstream_ip_hash_module',
#        '--without-http_upstream_least_conn_module',
#        '--without-http_upstream_random_module',
#        '--without-http_upstream_keepalive_module',
#        '--without-http_upstream_zone_module', '--without-http',
#        '--without-http-cache', '--without-mail_pop3_module',
#        '--without-mail_imap_module', '--without-mail_smtp_module',
#        '--without-stream_limit_conn_module', '--without-stream_access_module',
#        '--without-stream_geo_module', '--without-stream_map_module',
#        '--without-stream_split_clients_module',
#        '--without-stream_return_module',
#        '--without-stream_upstream_hash_module',
#        '--without-stream_upstream_least_conn_module',
#        '--without-stream_upstream_random_module',
#        '--without-stream_upstream_zone_module', 'binary-size', 'unit',
#        'nr-of-gadgets'],
#       dtype='object')

# %%
# features to consider
fts = list(odf.columns.values)
fts.remove('nr-of-gadgets')
fts.remove('binary-size')
fts.remove('unit')
fts
# Out:
# ['--with-select_module',
#  '--with-poll_module',
#  '--with-threads',
#  '--with-file-aio',
#  '--with-http_ssl_module',
#  '--with-http_v2_module',
#  '--with-http_realip_module',
#  '--with-http_addition_module',
#  '--with-http_xslt_module',
#  '--with-http_xslt_module=dynamic',
#  '--with-http_image_filter_module',
#  '--with-http_image_filter_module=dynamic',
#  '--with-http_geoip_module',
#  '--with-http_geoip_module=dynamic',
#  '--with-http_sub_module',
#  '--with-http_dav_module',
#  '--with-http_flv_module',
#  '--with-http_mp4_module',
#  '--with-http_gunzip_module',
#  '--with-http_gzip_static_module',
#  '--with-http_auth_request_module',
#  '--with-http_random_index_module',
#  '--with-http_secure_link_module',
#  '--with-http_degradation_module',
#  '--with-http_slice_module',
#  '--with-http_stub_status_module',
#  '--with-http_perl_module=dynamic',
#  '--with-mail',
#  '--with-mail=dynamic',
#  '--with-mail_ssl_module',
#  '--with-stream',
#  '--with-stream=dynamic',
#  '--with-stream_ssl_module',
#  '--with-stream_realip_module',
#  '--with-stream_geoip_module',
#  '--with-stream_geoip_module=dynamic',
#  '--with-stream_ssl_preread_module',
#  '--with-google_perftools_module',
#  '--with-compat',
#  '--with-pcre',
#  '--with-pcre-jit',
#  '--with-zlib-asm=CPU',
#  '--with-libatomic',
#  '--with-debug',
#  '--without-select_module',
#  '--without-poll_module',
#  '--without-http_charset_module',
#  '--without-http_gzip_module',
#  '--without-http_ssi_module',
#  '--without-http_userid_module',
#  '--without-http_access_module',
#  '--without-http_auth_basic_module',
#  '--without-http_mirror_module',
#  '--without-http_autoindex_module',
#  '--without-http_geo_module',
#  '--without-http_map_module',
#  '--without-http_split_clients_module',
#  '--without-http_referer_module',
#  '--without-http_rewrite_module',
#  '--without-http_proxy_module',
#  '--without-http_fastcgi_module',
#  '--without-http_uwsgi_module',
#  '--without-http_scgi_module',
#  '--without-http_grpc_module',
#  '--without-http_memcached_module',
#  '--without-http_limit_conn_module',
#  '--without-http_limit_req_module',
#  '--without-http_empty_gif_module',
#  '--without-http_browser_module',
#  '--without-http_upstream_hash_module',
#  '--without-http_upstream_ip_hash_module',
#  '--without-http_upstream_least_conn_module',
#  '--without-http_upstream_random_module',
#  '--without-http_upstream_keepalive_module',
#  '--without-http_upstream_zone_module',
#  '--without-http',
#  '--without-http-cache',
#  '--without-mail_pop3_module',
#  '--without-mail_imap_module',
#  '--without-mail_smtp_module',
#  '--without-stream_limit_conn_module',
#  '--without-stream_access_module',
#  '--without-stream_geo_module',
#  '--without-stream_map_module',
#  '--without-stream_split_clients_module',
#  '--without-stream_return_module',
#  '--without-stream_upstream_hash_module',
#  '--without-stream_upstream_least_conn_module',
#  '--without-stream_upstream_random_module',
#  '--without-stream_upstream_zone_module']

# %%
odf['binary-size'].plot(kind='box')

# %%
odf['binary-size'].plot(kind='hist')

# %%
odf['nr-of-gadgets'].plot(kind='box')

# %%
odf['nr-of-gadgets'].plot(kind='hist')

# %%
from sklearn.model_selection import train_test_split
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
import graphviz 

def mean_absolute_percentage_error(y_pred, y_true):
    return np.average(np.abs(y_pred - y_true) / np.abs(y_true))

def eval_model(target, y_pred, X_test, y_test): 
    print('Mean squared error: %.2f'
          % mean_squared_error(y_test, y_pred))
    # The coefficient of determination: 1 is perfect prediction
    print('Coefficient of determination: %.2f'
          % r2_score(y_test, y_pred))
    
    print("MAPE", mean_absolute_percentage_error(y_pred, y_test))

    # Plot outputs
    plt.scatter(X_test.index, y_test,  color='black')
    plt.plot(X_test.index, y_pred, color='blue', linewidth=3)

    plt.xticks(())
    plt.yticks(())

    plt.show()

def mk_linear_regression(target, test_size=0.8):
    regr = linear_model.LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(odf[fts], odf[target], test_size=test_size, random_state=42)
    regr.fit(X_train, y_train)
    print(regr.coef_)
    coeffs = pd.DataFrame(regr.coef_, fts, columns=['Coefficients'])
    print(coeffs.sort_values(by="Coefficients"))
    coeffs.plot(kind='barh', figsize=(9, 7))
    plt.axvline(x=0, color='.5')
    plt.subplots_adjust(left=.3)
    plt.show()
    
    y_pred = regr.predict(X_test)
    eval_model(target, y_pred, X_test, y_test)
    



def mk_treepredictor(target, decision_tree, test_size=0.8): 
    if decision_tree:
        clf = tree.DecisionTreeRegressor()
    else:
        clf = RandomForestRegressor() 
    X_train, X_test, y_train, y_test = train_test_split(odf[fts], odf[target], test_size=test_size, random_state=42)
   
    clf = clf.fit(X_train, y_train)

    if decision_tree:
        dot_data = tree.export_graphviz(clf, out_file=None, feature_names=fts,  
                      filled=True, rounded=True,  
                      special_characters=True)
        graph = graphviz.Source(dot_data) 
        graph.render(SYSTEM_NAME)
                   
    
    y_pred = clf.predict(X_test)
    eval_model(target, y_pred, X_test, y_test)
    
    importance = clf.feature_importances_
    for i, v in enumerate(importance):
        print('Feature: %d, %s, Score: %.5f' % (i, odf.columns[i], v))
    plt.bar([x for x in range(len(importance))], importance)
    plt.show()
    
mk_linear_regression('binary-size')
mk_treepredictor('binary-size', True)
mk_treepredictor('binary-size', False)
# Out:
# [  207606.76465298   357103.92416508  -106966.38194428   -32138.45322372
#    -58144.02134759   140495.3512293    137654.5999226    116222.31630912
#    195542.22813548   -97817.2242661     21477.72918705  -171235.48683707
#    -84663.19961045    16139.73166958   -12876.78970303  -105716.73276136
#    198017.33900426  -170059.50401383     5690.41725612  -140707.19333682
#    213761.9424326   -142513.97274405     5201.04797813    30688.5018533
#    211317.63118082  -377388.83977965   -31171.65478255   233363.72174269
#   -117101.26243565   174444.62334502   279610.77524872   -85494.6758194
#    -36839.28064785    80403.18903201   124403.5884391     72839.69245653
#    -53004.15977589   231912.46361274    60153.78866135  -162355.25171982
#    -27490.05639444   148521.41640041  -110535.70616552   -61004.53562662
#   -480609.58492589   -65170.42514749    34920.40609983  -137140.67872115
#   -115292.26252631   239074.02881277    69875.29069215   134153.3790734
#    287708.57582086    88971.36826225  -180600.23450837   169028.4132516
#     41879.47304121  -109583.07520277    62348.61719318   166708.07486658
#     84932.63569149    13153.05359774   -56568.30574005    54270.95584602
#    122299.88982611   213593.81900143   333633.82368188   314347.27460807
#   -101293.87227319   -56603.97391479   107201.09331691   -74103.19144331
#   -112235.22554754   108429.18129832   -12807.58280833 -1153889.43903183
#    -11459.51886627    50471.4290235   -221184.63934137   176244.72332675
#     -3389.03127496  -191684.74572631   122802.52895584  -191575.33360921
#    130319.84294049     3459.20567289   -93370.48468823   -66765.51876645
#   -166467.45604281  -347895.19085043]
#                                        Coefficients
# --without-http                        -1.153889e+06
# --without-select_module               -4.806096e+05
# --with-http_stub_status_module        -3.773888e+05
# --without-stream_upstream_zone_module -3.478952e+05
# --without-mail_imap_module            -2.211846e+05
# ...                                             ...
# --with-stream                          2.796108e+05
# --without-http_mirror_module           2.877086e+05
# --without-http_empty_gif_module        3.143473e+05
# --without-http_limit_req_module        3.336338e+05
# --with-poll_module                     3.571039e+05
#
# [90 rows x 1 columns]
# Mean squared error: 1400749905384.23
# Coefficient of determination: 0.38
# MAPE 0.3437686398912622
# Mean squared error: 375303238889.20
# Coefficient of determination: 0.83
# MAPE 0.17425734299040102
# Feature: 0, --with-select_module, Score: 0.00000
# Feature: 1, --with-poll_module, Score: 0.01845
# Feature: 2, --with-threads, Score: 0.00000
# Feature: 3, --with-file-aio, Score: 0.00000
# Feature: 4, --with-http_ssl_module, Score: 0.00327
# Feature: 5, --with-http_v2_module, Score: 0.00000
# Feature: 6, --with-http_realip_module, Score: 0.00000
# Feature: 7, --with-http_addition_module, Score: 0.00000
# Feature: 8, --with-http_xslt_module, Score: 0.00000
# Feature: 9, --with-http_xslt_module=dynamic, Score: 0.00000
# Feature: 10, --with-http_image_filter_module, Score: 0.00000
# Feature: 11, --with-http_image_filter_module=dynamic, Score: 0.00012
# Feature: 12, --with-http_geoip_module, Score: 0.00000
# Feature: 13, --with-http_geoip_module=dynamic, Score: 0.00001
# Feature: 14, --with-http_sub_module, Score: 0.00000
# Feature: 15, --with-http_dav_module, Score: 0.00000
# Feature: 16, --with-http_flv_module, Score: 0.00012
# Feature: 17, --with-http_mp4_module, Score: 0.00002
# Feature: 18, --with-http_gunzip_module, Score: 0.00000
# Feature: 19, --with-http_gzip_static_module, Score: 0.00001
# Feature: 20, --with-http_auth_request_module, Score: 0.00000
# Feature: 21, --with-http_random_index_module, Score: 0.00000
# Feature: 22, --with-http_secure_link_module, Score: 0.00000
# Feature: 23, --with-http_degradation_module, Score: 0.00119
# Feature: 24, --with-http_slice_module, Score: 0.00050
# Feature: 25, --with-http_stub_status_module, Score: 0.00000
# Feature: 26, --with-http_perl_module=dynamic, Score: 0.00000
# Feature: 27, --with-mail, Score: 0.00000
# Feature: 28, --with-mail=dynamic, Score: 0.00179
# Feature: 29, --with-mail_ssl_module, Score: 0.00000
# Feature: 30, --with-stream, Score: 0.00000
# Feature: 31, --with-stream=dynamic, Score: 0.01145
# Feature: 32, --with-stream_ssl_module, Score: 0.00000
# Feature: 33, --with-stream_realip_module, Score: 0.00000
# Feature: 34, --with-stream_geoip_module, Score: 0.00000
# Feature: 35, --with-stream_geoip_module=dynamic, Score: 0.00061
# Feature: 36, --with-stream_ssl_preread_module, Score: 0.00000
# Feature: 37, --with-google_perftools_module, Score: 0.00000
# Feature: 38, --with-compat, Score: 0.00000
# Feature: 39, --with-pcre, Score: 0.00000
# Feature: 40, --with-pcre-jit, Score: 0.00000
# Feature: 41, --with-zlib-asm=CPU, Score: 0.01560
# Feature: 42, --with-libatomic, Score: 0.00001
# Feature: 43, --with-debug, Score: 0.00049
# Feature: 44, --without-select_module, Score: 0.00000
# Feature: 45, --without-poll_module, Score: 0.00000
# Feature: 46, --without-http_charset_module, Score: 0.00000
# Feature: 47, --without-http_gzip_module, Score: 0.01106
# Feature: 48, --without-http_ssi_module, Score: 0.00382
# Feature: 49, --without-http_userid_module, Score: 0.00000
# Feature: 50, --without-http_access_module, Score: 0.00000
# Feature: 51, --without-http_auth_basic_module, Score: 0.00002
# Feature: 52, --without-http_mirror_module, Score: 0.00000
# Feature: 53, --without-http_autoindex_module, Score: 0.00000
# Feature: 54, --without-http_geo_module, Score: 0.00000
# Feature: 55, --without-http_map_module, Score: 0.00000
# Feature: 56, --without-http_split_clients_module, Score: 0.00000
# Feature: 57, --without-http_referer_module, Score: 0.00001
# Feature: 58, --without-http_rewrite_module, Score: 0.00000
# Feature: 59, --without-http_proxy_module, Score: 0.00046
# Feature: 60, --without-http_fastcgi_module, Score: 0.00000
# Feature: 61, --without-http_uwsgi_module, Score: 0.00009
# Feature: 62, --without-http_scgi_module, Score: 0.00265
# Feature: 63, --without-http_grpc_module, Score: 0.00000
# Feature: 64, --without-http_memcached_module, Score: 0.00004
# Feature: 65, --without-http_limit_conn_module, Score: 0.00000
# Feature: 66, --without-http_limit_req_module, Score: 0.00000
# Feature: 67, --without-http_empty_gif_module, Score: 0.00000
# Feature: 68, --without-http_browser_module, Score: 0.00000
# Feature: 69, --without-http_upstream_hash_module, Score: 0.00000
# Feature: 70, --without-http_upstream_ip_hash_module, Score: 0.00000
# Feature: 71, --without-http_upstream_least_conn_module, Score: 0.00153
# Feature: 72, --without-http_upstream_random_module, Score: 0.00000
# Feature: 73, --without-http_upstream_keepalive_module, Score: 0.00000
# Feature: 74, --without-http_upstream_zone_module, Score: 0.00089
# Feature: 75, --without-http, Score: 0.92336
# Feature: 76, --without-http-cache, Score: 0.00000
# Feature: 77, --without-mail_pop3_module, Score: 0.00000
# Feature: 78, --without-mail_imap_module, Score: 0.00000
# Feature: 79, --without-mail_smtp_module, Score: 0.00000
# Feature: 80, --without-stream_limit_conn_module, Score: 0.00000
# Feature: 81, --without-stream_access_module, Score: 0.00000
# Feature: 82, --without-stream_geo_module, Score: 0.00240
# Feature: 83, --without-stream_map_module, Score: 0.00000
# Feature: 84, --without-stream_split_clients_module, Score: 0.00000
# Feature: 85, --without-stream_return_module, Score: 0.00000
# Feature: 86, --without-stream_upstream_hash_module, Score: 0.00000
# Feature: 87, --without-stream_upstream_least_conn_module, Score: 0.00003
# Feature: 88, --without-stream_upstream_random_module, Score: 0.00000
# Feature: 89, --without-stream_upstream_zone_module, Score: 0.00000
# Mean squared error: 193220418958.00
# Coefficient of determination: 0.91
# MAPE 0.13272849422849725
# Feature: 0, --with-select_module, Score: 0.00009
# Feature: 1, --with-poll_module, Score: 0.01106
# Feature: 2, --with-threads, Score: 0.00141
# Feature: 3, --with-file-aio, Score: 0.00063
# Feature: 4, --with-http_ssl_module, Score: 0.00052
# Feature: 5, --with-http_v2_module, Score: 0.00056
# Feature: 6, --with-http_realip_module, Score: 0.00077
# Feature: 7, --with-http_addition_module, Score: 0.00012
# Feature: 8, --with-http_xslt_module, Score: 0.00093
# Feature: 9, --with-http_xslt_module=dynamic, Score: 0.00010
# Feature: 10, --with-http_image_filter_module, Score: 0.00078
# Feature: 11, --with-http_image_filter_module=dynamic, Score: 0.00111
# Feature: 12, --with-http_geoip_module, Score: 0.00020
# Feature: 13, --with-http_geoip_module=dynamic, Score: 0.00037
# Feature: 14, --with-http_sub_module, Score: 0.00083
# Feature: 15, --with-http_dav_module, Score: 0.00040
# Feature: 16, --with-http_flv_module, Score: 0.00099
# Feature: 17, --with-http_mp4_module, Score: 0.00013
# Feature: 18, --with-http_gunzip_module, Score: 0.00027
# Feature: 19, --with-http_gzip_static_module, Score: 0.00070
# Feature: 20, --with-http_auth_request_module, Score: 0.00016
# Feature: 21, --with-http_random_index_module, Score: 0.00010
# Feature: 22, --with-http_secure_link_module, Score: 0.00035
# Feature: 23, --with-http_degradation_module, Score: 0.00137
# Feature: 24, --with-http_slice_module, Score: 0.00021
# Feature: 25, --with-http_stub_status_module, Score: 0.00038
# Feature: 26, --with-http_perl_module=dynamic, Score: 0.00063
# Feature: 27, --with-mail, Score: 0.00210
# Feature: 28, --with-mail=dynamic, Score: 0.00075
# Feature: 29, --with-mail_ssl_module, Score: 0.00048
# Feature: 30, --with-stream, Score: 0.00600
# Feature: 31, --with-stream=dynamic, Score: 0.00099
# Feature: 32, --with-stream_ssl_module, Score: 0.00097
# Feature: 33, --with-stream_realip_module, Score: 0.00022
# Feature: 34, --with-stream_geoip_module, Score: 0.00021
# Feature: 35, --with-stream_geoip_module=dynamic, Score: 0.00046
# Feature: 36, --with-stream_ssl_preread_module, Score: 0.00014
# Feature: 37, --with-google_perftools_module, Score: 0.00168
# Feature: 38, --with-compat, Score: 0.00002
# Feature: 39, --with-pcre, Score: 0.00043
# Feature: 40, --with-pcre-jit, Score: 0.00010
# Feature: 41, --with-zlib-asm=CPU, Score: 0.00353
# Feature: 42, --with-libatomic, Score: 0.00035
# Feature: 43, --with-debug, Score: 0.00141
# Feature: 44, --without-select_module, Score: 0.00015
# Feature: 45, --without-poll_module, Score: 0.00011
# Feature: 46, --without-http_charset_module, Score: 0.00032
# Feature: 47, --without-http_gzip_module, Score: 0.00316
# Feature: 48, --without-http_ssi_module, Score: 0.00230
# Feature: 49, --without-http_userid_module, Score: 0.00034
# Feature: 50, --without-http_access_module, Score: 0.00006
# Feature: 51, --without-http_auth_basic_module, Score: 0.00068
# Feature: 52, --without-http_mirror_module, Score: 0.00045
# Feature: 53, --without-http_autoindex_module, Score: 0.00031
# Feature: 54, --without-http_geo_module, Score: 0.00134
# Feature: 55, --without-http_map_module, Score: 0.00025
# Feature: 56, --without-http_split_clients_module, Score: 0.00202
# Feature: 57, --without-http_referer_module, Score: 0.00015
# Feature: 58, --without-http_rewrite_module, Score: 0.00037
# Feature: 59, --without-http_proxy_module, Score: 0.00029
# Feature: 60, --without-http_fastcgi_module, Score: 0.00024
# Feature: 61, --without-http_uwsgi_module, Score: 0.00040
# Feature: 62, --without-http_scgi_module, Score: 0.00047
# Feature: 63, --without-http_grpc_module, Score: 0.00010
# Feature: 64, --without-http_memcached_module, Score: 0.00010
# Feature: 65, --without-http_limit_conn_module, Score: 0.00052
# Feature: 66, --without-http_limit_req_module, Score: 0.00037
# Feature: 67, --without-http_empty_gif_module, Score: 0.00040
# Feature: 68, --without-http_browser_module, Score: 0.00330
# Feature: 69, --without-http_upstream_hash_module, Score: 0.00087
# Feature: 70, --without-http_upstream_ip_hash_module, Score: 0.00095
# Feature: 71, --without-http_upstream_least_conn_module, Score: 0.00046
# Feature: 72, --without-http_upstream_random_module, Score: 0.00141
# Feature: 73, --without-http_upstream_keepalive_module, Score: 0.00016
# Feature: 74, --without-http_upstream_zone_module, Score: 0.00056
# Feature: 75, --without-http, Score: 0.92601
# Feature: 76, --without-http-cache, Score: 0.00013
# Feature: 77, --without-mail_pop3_module, Score: 0.00021
# Feature: 78, --without-mail_imap_module, Score: 0.00015
# Feature: 79, --without-mail_smtp_module, Score: 0.00031
# Feature: 80, --without-stream_limit_conn_module, Score: 0.00018
# Feature: 81, --without-stream_access_module, Score: 0.00030
# Feature: 82, --without-stream_geo_module, Score: 0.00204
# Feature: 83, --without-stream_map_module, Score: 0.00032
# Feature: 84, --without-stream_split_clients_module, Score: 0.00005
# Feature: 85, --without-stream_return_module, Score: 0.00105
# Feature: 86, --without-stream_upstream_hash_module, Score: 0.00088
# Feature: 87, --without-stream_upstream_least_conn_module, Score: 0.00031
# Feature: 88, --without-stream_upstream_random_module, Score: 0.00030
# Feature: 89, --without-stream_upstream_zone_module, Score: 0.00012

# %%
mk_linear_regression('nr-of-gadgets')
mk_treepredictor('nr-of-gadgets', True)
mk_treepredictor('nr-of-gadgets', False)
# Out:
# [ 1420.39200669  2061.20250502  -475.23931893  -270.24782037
#   -273.48727556   787.65872292   553.74995625   699.91105728
#   1169.65123597  -499.62844395    78.52744657 -1192.87032486
#   -497.94171669    98.87346527   -36.88618447  -717.34724692
#   1146.5653687   -989.05525445   -67.70457273  -809.39200738
#   1303.39729513  -837.38363128    86.40559945   190.60744395
#   1182.33734032 -2234.60933757  -280.59076636  1453.90587167
#   -598.89834109  1136.6113793   1519.09779841  -422.82600872
#   -214.59613889   473.36209613   604.45779475   295.93255685
#   -271.9055656   1157.65080903   293.85945926  -921.62780795
#   -252.17451291   797.91043337  -686.85928895  -329.36788787
#  -2780.80404817  -350.93526285   262.82202837  -642.05243544
#   -707.19130311  1592.53724867   406.77833422   907.1533608
#   1559.95763702   622.74116659 -1077.59688762   997.83845302
#    361.15382074  -748.93968602   276.55244103   849.24538067
#    459.33580018   -40.27510553  -309.96087928   231.89884013
#    716.11510438  1189.67982895  1746.58754436  1830.58384285
#   -550.08182755  -211.62416056   745.22809735  -325.00862308
#   -672.81400129   683.73399649  -124.95908779 -6750.59904261
#      7.33399145   277.49533835 -1213.59885383   919.24069149
#     35.46733241  -930.19602419   768.51629732 -1090.20346406
#    688.54073906    39.95347738  -667.0892122   -434.95619402
#   -875.49334505 -2049.96336174]
#                                        Coefficients
# --without-http                         -6750.599043
# --without-select_module                -2780.804048
# --with-http_stub_status_module         -2234.609338
# --without-stream_upstream_zone_module  -2049.963362
# --without-mail_imap_module             -1213.598854
# ...                                             ...
# --without-http_mirror_module            1559.957637
# --without-http_userid_module            1592.537249
# --without-http_limit_req_module         1746.587544
# --without-http_empty_gif_module         1830.583843
# --with-poll_module                      2061.202505
#
# [90 rows x 1 columns]
# Mean squared error: 48638679.36
# Coefficient of determination: 0.36
# MAPE 0.26726717156230795
# Mean squared error: 13046157.94
# Coefficient of determination: 0.83
# MAPE 0.13326225376784068
# Feature: 0, --with-select_module, Score: 0.00000
# Feature: 1, --with-poll_module, Score: 0.02239
# Feature: 2, --with-threads, Score: 0.00000
# Feature: 3, --with-file-aio, Score: 0.00000
# Feature: 4, --with-http_ssl_module, Score: 0.00291
# Feature: 5, --with-http_v2_module, Score: 0.00009
# Feature: 6, --with-http_realip_module, Score: 0.00000
# Feature: 7, --with-http_addition_module, Score: 0.00000
# Feature: 8, --with-http_xslt_module, Score: 0.00000
# Feature: 9, --with-http_xslt_module=dynamic, Score: 0.00000
# Feature: 10, --with-http_image_filter_module, Score: 0.00000
# Feature: 11, --with-http_image_filter_module=dynamic, Score: 0.00000
# Feature: 12, --with-http_geoip_module, Score: 0.00013
# Feature: 13, --with-http_geoip_module=dynamic, Score: 0.00000
# Feature: 14, --with-http_sub_module, Score: 0.00000
# Feature: 15, --with-http_dav_module, Score: 0.00000
# Feature: 16, --with-http_flv_module, Score: 0.00000
# Feature: 17, --with-http_mp4_module, Score: 0.00000
# Feature: 18, --with-http_gunzip_module, Score: 0.00000
# Feature: 19, --with-http_gzip_static_module, Score: 0.00000
# Feature: 20, --with-http_auth_request_module, Score: 0.00000
# Feature: 21, --with-http_random_index_module, Score: 0.00000
# Feature: 22, --with-http_secure_link_module, Score: 0.00000
# Feature: 23, --with-http_degradation_module, Score: 0.00000
# Feature: 24, --with-http_slice_module, Score: 0.00262
# Feature: 25, --with-http_stub_status_module, Score: 0.00000
# Feature: 26, --with-http_perl_module=dynamic, Score: 0.00000
# Feature: 27, --with-mail, Score: 0.00102
# Feature: 28, --with-mail=dynamic, Score: 0.00000
# Feature: 29, --with-mail_ssl_module, Score: 0.00178
# Feature: 30, --with-stream, Score: 0.00000
# Feature: 31, --with-stream=dynamic, Score: 0.01058
# Feature: 32, --with-stream_ssl_module, Score: 0.00000
# Feature: 33, --with-stream_realip_module, Score: 0.00000
# Feature: 34, --with-stream_geoip_module, Score: 0.00000
# Feature: 35, --with-stream_geoip_module=dynamic, Score: 0.00000
# Feature: 36, --with-stream_ssl_preread_module, Score: 0.00000
# Feature: 37, --with-google_perftools_module, Score: 0.00000
# Feature: 38, --with-compat, Score: 0.00000
# Feature: 39, --with-pcre, Score: 0.00000
# Feature: 40, --with-pcre-jit, Score: 0.00000
# Feature: 41, --with-zlib-asm=CPU, Score: 0.01360
# Feature: 42, --with-libatomic, Score: 0.00011
# Feature: 43, --with-debug, Score: 0.00001
# Feature: 44, --without-select_module, Score: 0.00000
# Feature: 45, --without-poll_module, Score: 0.00002
# Feature: 46, --without-http_charset_module, Score: 0.00000
# Feature: 47, --without-http_gzip_module, Score: 0.01255
# Feature: 48, --without-http_ssi_module, Score: 0.00432
# Feature: 49, --without-http_userid_module, Score: 0.00004
# Feature: 50, --without-http_access_module, Score: 0.00000
# Feature: 51, --without-http_auth_basic_module, Score: 0.00000
# Feature: 52, --without-http_mirror_module, Score: 0.00000
# Feature: 53, --without-http_autoindex_module, Score: 0.00000
# Feature: 54, --without-http_geo_module, Score: 0.00000
# Feature: 55, --without-http_map_module, Score: 0.00000
# Feature: 56, --without-http_split_clients_module, Score: 0.00091
# Feature: 57, --without-http_referer_module, Score: 0.00008
# Feature: 58, --without-http_rewrite_module, Score: 0.00000
# Feature: 59, --without-http_proxy_module, Score: 0.00000
# Feature: 60, --without-http_fastcgi_module, Score: 0.00000
# Feature: 61, --without-http_uwsgi_module, Score: 0.00000
# Feature: 62, --without-http_scgi_module, Score: 0.00037
# Feature: 63, --without-http_grpc_module, Score: 0.00000
# Feature: 64, --without-http_memcached_module, Score: 0.00000
# Feature: 65, --without-http_limit_conn_module, Score: 0.00000
# Feature: 66, --without-http_limit_req_module, Score: 0.00000
# Feature: 67, --without-http_empty_gif_module, Score: 0.00011
# Feature: 68, --without-http_browser_module, Score: 0.00000
# Feature: 69, --without-http_upstream_hash_module, Score: 0.00000
# Feature: 70, --without-http_upstream_ip_hash_module, Score: 0.00124
# Feature: 71, --without-http_upstream_least_conn_module, Score: 0.00000
# Feature: 72, --without-http_upstream_random_module, Score: 0.00009
# Feature: 73, --without-http_upstream_keepalive_module, Score: 0.00000
# Feature: 74, --without-http_upstream_zone_module, Score: 0.00005
# Feature: 75, --without-http, Score: 0.91812
# Feature: 76, --without-http-cache, Score: 0.00000
# Feature: 77, --without-mail_pop3_module, Score: 0.00000
# Feature: 78, --without-mail_imap_module, Score: 0.00172
# Feature: 79, --without-mail_smtp_module, Score: 0.00000
# Feature: 80, --without-stream_limit_conn_module, Score: 0.00000
# Feature: 81, --without-stream_access_module, Score: 0.00000
# Feature: 82, --without-stream_geo_module, Score: 0.00149
# Feature: 83, --without-stream_map_module, Score: 0.00296
# Feature: 84, --without-stream_split_clients_module, Score: 0.00000
# Feature: 85, --without-stream_return_module, Score: 0.00067
# Feature: 86, --without-stream_upstream_hash_module, Score: 0.00000
# Feature: 87, --without-stream_upstream_least_conn_module, Score: 0.00000
# Feature: 88, --without-stream_upstream_random_module, Score: 0.00000
# Feature: 89, --without-stream_upstream_zone_module, Score: 0.00000
# Mean squared error: 7323315.55
# Coefficient of determination: 0.90
# MAPE 0.10792362061646817
# Feature: 0, --with-select_module, Score: 0.00057
# Feature: 1, --with-poll_module, Score: 0.01383
# Feature: 2, --with-threads, Score: 0.00108
# Feature: 3, --with-file-aio, Score: 0.00027
# Feature: 4, --with-http_ssl_module, Score: 0.00041
# Feature: 5, --with-http_v2_module, Score: 0.00034
# Feature: 6, --with-http_realip_module, Score: 0.00038
# Feature: 7, --with-http_addition_module, Score: 0.00096
# Feature: 8, --with-http_xslt_module, Score: 0.00105
# Feature: 9, --with-http_xslt_module=dynamic, Score: 0.00029
# Feature: 10, --with-http_image_filter_module, Score: 0.00119
# Feature: 11, --with-http_image_filter_module=dynamic, Score: 0.00091
# Feature: 12, --with-http_geoip_module, Score: 0.00019
# Feature: 13, --with-http_geoip_module=dynamic, Score: 0.00027
# Feature: 14, --with-http_sub_module, Score: 0.00116
# Feature: 15, --with-http_dav_module, Score: 0.00101
# Feature: 16, --with-http_flv_module, Score: 0.00084
# Feature: 17, --with-http_mp4_module, Score: 0.00025
# Feature: 18, --with-http_gunzip_module, Score: 0.00020
# Feature: 19, --with-http_gzip_static_module, Score: 0.00103
# Feature: 20, --with-http_auth_request_module, Score: 0.00047
# Feature: 21, --with-http_random_index_module, Score: 0.00161
# Feature: 22, --with-http_secure_link_module, Score: 0.00023
# Feature: 23, --with-http_degradation_module, Score: 0.00054
# Feature: 24, --with-http_slice_module, Score: 0.00033
# Feature: 25, --with-http_stub_status_module, Score: 0.00056
# Feature: 26, --with-http_perl_module=dynamic, Score: 0.00073
# Feature: 27, --with-mail, Score: 0.00582
# Feature: 28, --with-mail=dynamic, Score: 0.00039
# Feature: 29, --with-mail_ssl_module, Score: 0.00119
# Feature: 30, --with-stream, Score: 0.00307
# Feature: 31, --with-stream=dynamic, Score: 0.00079
# Feature: 32, --with-stream_ssl_module, Score: 0.00039
# Feature: 33, --with-stream_realip_module, Score: 0.00006
# Feature: 34, --with-stream_geoip_module, Score: 0.00012
# Feature: 35, --with-stream_geoip_module=dynamic, Score: 0.00017
# Feature: 36, --with-stream_ssl_preread_module, Score: 0.00048
# Feature: 37, --with-google_perftools_module, Score: 0.00077
# Feature: 38, --with-compat, Score: 0.00024
# Feature: 39, --with-pcre, Score: 0.00017
# Feature: 40, --with-pcre-jit, Score: 0.00017
# Feature: 41, --with-zlib-asm=CPU, Score: 0.00294
# Feature: 42, --with-libatomic, Score: 0.00041
# Feature: 43, --with-debug, Score: 0.00245
# Feature: 44, --without-select_module, Score: 0.00063
# Feature: 45, --without-poll_module, Score: 0.00040
# Feature: 46, --without-http_charset_module, Score: 0.00016
# Feature: 47, --without-http_gzip_module, Score: 0.00360
# Feature: 48, --without-http_ssi_module, Score: 0.00396
# Feature: 49, --without-http_userid_module, Score: 0.00020
# Feature: 50, --without-http_access_module, Score: 0.00023
# Feature: 51, --without-http_auth_basic_module, Score: 0.00039
# Feature: 52, --without-http_mirror_module, Score: 0.00023
# Feature: 53, --without-http_autoindex_module, Score: 0.00034
# Feature: 54, --without-http_geo_module, Score: 0.00060
# Feature: 55, --without-http_map_module, Score: 0.00080
# Feature: 56, --without-http_split_clients_module, Score: 0.00148
# Feature: 57, --without-http_referer_module, Score: 0.00075
# Feature: 58, --without-http_rewrite_module, Score: 0.00071
# Feature: 59, --without-http_proxy_module, Score: 0.00012
# Feature: 60, --without-http_fastcgi_module, Score: 0.00029
# Feature: 61, --without-http_uwsgi_module, Score: 0.00061
# Feature: 62, --without-http_scgi_module, Score: 0.00047
# Feature: 63, --without-http_grpc_module, Score: 0.00011
# Feature: 64, --without-http_memcached_module, Score: 0.00012
# Feature: 65, --without-http_limit_conn_module, Score: 0.00031
# Feature: 66, --without-http_limit_req_module, Score: 0.00068
# Feature: 67, --without-http_empty_gif_module, Score: 0.00016
# Feature: 68, --without-http_browser_module, Score: 0.00105
# Feature: 69, --without-http_upstream_hash_module, Score: 0.00092
# Feature: 70, --without-http_upstream_ip_hash_module, Score: 0.00045
# Feature: 71, --without-http_upstream_least_conn_module, Score: 0.00032
# Feature: 72, --without-http_upstream_random_module, Score: 0.00120
# Feature: 73, --without-http_upstream_keepalive_module, Score: 0.00239
# Feature: 74, --without-http_upstream_zone_module, Score: 0.00023
# Feature: 75, --without-http, Score: 0.91814
# Feature: 76, --without-http-cache, Score: 0.00027
# Feature: 77, --without-mail_pop3_module, Score: 0.00005
# Feature: 78, --without-mail_imap_module, Score: 0.00036
# Feature: 79, --without-mail_smtp_module, Score: 0.00034
# Feature: 80, --without-stream_limit_conn_module, Score: 0.00009
# Feature: 81, --without-stream_access_module, Score: 0.00012
# Feature: 82, --without-stream_geo_module, Score: 0.00317
# Feature: 83, --without-stream_map_module, Score: 0.00066
# Feature: 84, --without-stream_split_clients_module, Score: 0.00004
# Feature: 85, --without-stream_return_module, Score: 0.00050
# Feature: 86, --without-stream_upstream_hash_module, Score: 0.00087
# Feature: 87, --without-stream_upstream_least_conn_module, Score: 0.00035
# Feature: 88, --without-stream_upstream_random_module, Score: 0.00042
# Feature: 89, --without-stream_upstream_zone_module, Score: 0.00036
