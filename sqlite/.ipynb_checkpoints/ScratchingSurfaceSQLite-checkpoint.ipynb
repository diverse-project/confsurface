# %%
import pandas as pd

DATASET='splc21-data - sqlite-200.csv'
SYSTEM_NAME='sqlite'

FTS=['--disable-option-checking', '--disable-libtool-lock',
       '--disable-largefile', '--disable-threadsafe', '--disable-tcl',
       '--disable-readline', '--disable-amalgamation',
       '--disable-load-extension', '--disable-math', '--enable-shared=no',
       '--enable-static', '--enable-fast-install', '--enable-releasemode',
       '--enable-tempstore', '--enable-editline', '--enable-debug',
       '--enable-all', '--enable-memsys5', '--enable-memsys3', '--enable-fts3',
       '--enable-fts4', '--enable-fts5', '--enable-json1',
       '--enable-update-limit', '--enable-geopoly', '--enable-rtree',
       '--enable-session', '--enable-gcov', '--with-pic', '--with-gnu-ld',
       '--with-tcl=/usr/lib64']

odf = pd.read_csv(DATASET)
odf.head()
# Out:
#    --disable-option-checking  --disable-libtool-lock  --disable-largefile  \
# 0                      False                   False                 True
# 1                      False                    True                 True
# 2                      False                    True                False
# 3                      False                    True                 True
# 4                       True                    True                False
#
#    --disable-threadsafe  --disable-tcl  --disable-readline  \
# 0                 False          False               False
# 1                 False          False                True
# 2                  True           True                True
# 3                  True          False               False
# 4                  True          False                True
#
#    --disable-amalgamation  --disable-load-extension  --disable-math  \
# 0                   False                     False            True
# 1                   False                     False           False
# 2                    True                     False           False
# 3                   False                     False           False
# 4                    True                      True            True
#
#    --enable-shared=no  ...  --enable-geopoly  --enable-rtree  \
# 0                True  ...             False            True
# 1               False  ...              True            True
# 2               False  ...             False           False
# 3                True  ...              True            True
# 4                True  ...             False            True
#
#    --enable-session  --enable-gcov  --with-pic  --with-gnu-ld  \
# 0             False          False        True          False
# 1              True           True        True          False
# 2             False          False       False          False
# 3              True          False        True          False
# 4             False          False       False           True
#
#    --with-tcl=/usr/lib64  binary-size   unit  nr-of-gadgets
# 0                   True      3892808  bytes          63180
# 1                  False      3615720  bytes          57865
# 2                   True      8522128  bytes          67350
# 3                  False     10153936  bytes          79939
# 4                  False      3968832  bytes          65233
#
# [5 rows x 34 columns]

# %%
odf.columns
# Out:
# Index(['--disable-option-checking', '--disable-libtool-lock',
#        '--disable-largefile', '--disable-threadsafe', '--disable-tcl',
#        '--disable-readline', '--disable-amalgamation',
#        '--disable-load-extension', '--disable-math', '--enable-shared=no',
#        '--enable-static', '--enable-fast-install', '--enable-releasemode',
#        '--enable-tempstore', '--enable-editline', '--enable-debug',
#        '--enable-all', '--enable-memsys5', '--enable-memsys3', '--enable-fts3',
#        '--enable-fts4', '--enable-fts5', '--enable-json1',
#        '--enable-update-limit', '--enable-geopoly', '--enable-rtree',
#        '--enable-session', '--enable-gcov', '--with-pic', '--with-gnu-ld',
#        '--with-tcl=/usr/lib64', 'binary-size', 'unit', 'nr-of-gadgets'],
#       dtype='object')

# %%
odf['binary-size'].plot(kind='box')

# %%
odf['binary-size'].plot(kind='hist')

# %%
odf['nr-of-gadgets'].plot(kind='box')

# %%
odf['nr-of-gadgets'].plot(kind='hist')

# %%
from sklearn.model_selection import train_test_split
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
import graphviz 

def mean_absolute_percentage_error(y_pred, y_true):
    return np.average(np.abs(y_pred - y_true) / np.abs(y_true))

def eval_model(target, y_pred, X_test, y_test): 
    print('Mean squared error: %.2f'
          % mean_squared_error(y_test, y_pred))
    # The coefficient of determination: 1 is perfect prediction
    print('Coefficient of determination: %.2f'
          % r2_score(y_test, y_pred))
    
    print("MAPE", mean_absolute_percentage_error(y_pred, y_test))

    # Plot outputs
    plt.scatter(X_test.index, y_test,  color='black')
    plt.plot(X_test.index, y_pred, color='blue', linewidth=3)

    plt.xticks(())
    plt.yticks(())

    plt.show()

def mk_linear_regression(target):
    regr = linear_model.LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(odf[FTS], odf[target], test_size=0.8, random_state=42)
    regr.fit(X_train, y_train)
    print(regr.coef_)
    coeffs = pd.DataFrame(regr.coef_, FTS, columns=['Coefficients'])
    print(coeffs.sort_values(by="Coefficients"))
    coeffs.plot(kind='barh', figsize=(9, 7))
    plt.axvline(x=0, color='.5')
    plt.subplots_adjust(left=.3)
    plt.show()
    
    y_pred = regr.predict(X_test)
    eval_model(target, y_pred, X_test, y_test)
    



def mk_treepredictor(target, decision_tree): 
    if decision_tree:
        clf = tree.DecisionTreeRegressor()
    else:
        clf = RandomForestRegressor() 
    X_train, X_test, y_train, y_test = train_test_split(odf[FTS], odf[target], test_size=0.8, random_state=42)
   
    clf = clf.fit(X_train, y_train)

    if decision_tree:
        dot_data = tree.export_graphviz(clf, out_file=None, feature_names=FTS,  
                      filled=True, rounded=True,  
                      special_characters=True)
        graph = graphviz.Source(dot_data) 
        graph.render(SYSTEM_NAME)
                   
    
    y_pred = clf.predict(X_test)
    eval_model(target, y_pred, X_test, y_test)
    
    importance = clf.feature_importances_
    for i, v in enumerate(importance):
        print('Feature: %d, %s, Score: %.5f' % (i, odf.columns[i], v))
    plt.bar([x for x in range(len(importance))], importance)
    plt.show()
    
mk_linear_regression('binary-size')
mk_treepredictor('binary-size', True)
mk_treepredictor('binary-size', False)
# Out:
# [ 1.94108609e+05 -2.76599179e+04 -2.57442009e+04 -3.85899098e+04
#  -9.70461336e+04  6.93014968e+04  1.69518265e+05 -3.53643575e+04
#  -1.36642340e+05  1.49470824e+05  1.61005857e+05 -1.61170723e+05
#  -1.37444741e+05  7.21814294e+04 -1.47499283e+05 -6.14279227e+06
#   3.23320419e+05  4.69875664e+04  3.30348530e+04 -1.99976235e+05
#  -1.30355460e+05  2.40224744e+05  4.62033899e+03  2.23091226e+05
#  -2.78112707e+05  7.65922430e+03  3.16636078e+04 -1.29833880e+05
#  -1.25258625e+05 -4.37198848e+04 -3.78844087e+05]
#                            Coefficients
# --enable-debug            -6.142792e+06
# --with-tcl=/usr/lib64     -3.788441e+05
# --enable-geopoly          -2.781127e+05
# --enable-fts3             -1.999762e+05
# --enable-fast-install     -1.611707e+05
# --enable-editline         -1.474993e+05
# --enable-releasemode      -1.374447e+05
# --disable-math            -1.366423e+05
# --enable-fts4             -1.303555e+05
# --enable-gcov             -1.298339e+05
# --with-pic                -1.252586e+05
# --disable-tcl             -9.704613e+04
# --with-gnu-ld             -4.371988e+04
# --disable-threadsafe      -3.858991e+04
# --disable-load-extension  -3.536436e+04
# --disable-libtool-lock    -2.765992e+04
# --disable-largefile       -2.574420e+04
# --enable-json1             4.620339e+03
# --enable-rtree             7.659224e+03
# --enable-session           3.166361e+04
# --enable-memsys3           3.303485e+04
# --enable-memsys5           4.698757e+04
# --disable-readline         6.930150e+04
# --enable-tempstore         7.218143e+04
# --enable-shared=no         1.494708e+05
# --enable-static            1.610059e+05
# --disable-amalgamation     1.695183e+05
# --disable-option-checking  1.941086e+05
# --enable-update-limit      2.230912e+05
# --enable-fts5              2.402247e+05
# --enable-all               3.233204e+05
# Mean squared error: 317453574686.88
# Coefficient of determination: 0.96
# MAPE 0.07251283792436873
# Mean squared error: 24541037639.20
# Coefficient of determination: 1.00
# MAPE 0.011586855312922594
# Feature: 0, --disable-option-checking, Score: 0.00000
# Feature: 1, --disable-libtool-lock, Score: 0.00000
# Feature: 2, --disable-largefile, Score: 0.00000
# Feature: 3, --disable-threadsafe, Score: 0.00013
# Feature: 4, --disable-tcl, Score: 0.00000
# Feature: 5, --disable-readline, Score: 0.00000
# Feature: 6, --disable-amalgamation, Score: 0.00002
# Feature: 7, --disable-load-extension, Score: 0.00000
# Feature: 8, --disable-math, Score: 0.00000
# Feature: 9, --enable-shared=no, Score: 0.00000
# Feature: 10, --enable-static, Score: 0.00000
# Feature: 11, --enable-fast-install, Score: 0.00002
# Feature: 12, --enable-releasemode, Score: 0.00000
# Feature: 13, --enable-tempstore, Score: 0.00000
# Feature: 14, --enable-editline, Score: 0.00002
# Feature: 15, --enable-debug, Score: 0.99285
# Feature: 16, --enable-all, Score: 0.00296
# Feature: 17, --enable-memsys5, Score: 0.00000
# Feature: 18, --enable-memsys3, Score: 0.00000
# Feature: 19, --enable-fts3, Score: 0.00000
# Feature: 20, --enable-fts4, Score: 0.00000
# Feature: 21, --enable-fts5, Score: 0.00386
# Feature: 22, --enable-json1, Score: 0.00000
# Feature: 23, --enable-update-limit, Score: 0.00000
# Feature: 24, --enable-geopoly, Score: 0.00000
# Feature: 25, --enable-rtree, Score: 0.00000
# Feature: 26, --enable-session, Score: 0.00011
# Feature: 27, --enable-gcov, Score: 0.00001
# Feature: 28, --with-pic, Score: 0.00000
# Feature: 29, --with-gnu-ld, Score: 0.00000
# Feature: 30, --with-tcl=/usr/lib64, Score: 0.00000
# Mean squared error: 178004616433.83
# Coefficient of determination: 0.98
# MAPE 0.029954547332593194
# Feature: 0, --disable-option-checking, Score: 0.00013
# Feature: 1, --disable-libtool-lock, Score: 0.00013
# Feature: 2, --disable-largefile, Score: 0.00018
# Feature: 3, --disable-threadsafe, Score: 0.00023
# Feature: 4, --disable-tcl, Score: 0.00008
# Feature: 5, --disable-readline, Score: 0.00023
# Feature: 6, --disable-amalgamation, Score: 0.00007
# Feature: 7, --disable-load-extension, Score: 0.00014
# Feature: 8, --disable-math, Score: 0.00052
# Feature: 9, --enable-shared=no, Score: 0.00011
# Feature: 10, --enable-static, Score: 0.00023
# Feature: 11, --enable-fast-install, Score: 0.00001
# Feature: 12, --enable-releasemode, Score: 0.00016
# Feature: 13, --enable-tempstore, Score: 0.00017
# Feature: 14, --enable-editline, Score: 0.00009
# Feature: 15, --enable-debug, Score: 0.99243
# Feature: 16, --enable-all, Score: 0.00266
# Feature: 17, --enable-memsys5, Score: 0.00003
# Feature: 18, --enable-memsys3, Score: 0.00002
# Feature: 19, --enable-fts3, Score: 0.00018
# Feature: 20, --enable-fts4, Score: 0.00003
# Feature: 21, --enable-fts5, Score: 0.00117
# Feature: 22, --enable-json1, Score: 0.00001
# Feature: 23, --enable-update-limit, Score: 0.00024
# Feature: 24, --enable-geopoly, Score: 0.00009
# Feature: 25, --enable-rtree, Score: 0.00001
# Feature: 26, --enable-session, Score: 0.00003
# Feature: 27, --enable-gcov, Score: 0.00014
# Feature: 28, --with-pic, Score: 0.00011
# Feature: 29, --with-gnu-ld, Score: 0.00000
# Feature: 30, --with-tcl=/usr/lib64, Score: 0.00038

# %%
mk_linear_regression('nr-of-gadgets')
mk_treepredictor('nr-of-gadgets', True)
mk_treepredictor('nr-of-gadgets', False)
# Out:
# [  -111.62096401    197.61327501  -1936.8645206     742.99123689
#    -310.7147377     910.50048947   2067.24952351    371.6746675
#   -1473.54620738   3623.96905856   1507.2628414   -3115.31488064
#   -1766.78906222  -1166.06369658    169.89426301 -16502.14270384
#    5965.54191679    274.58638114    890.95658798  -2530.14922636
#   -1795.9985212    1689.28046684    510.25859467   3490.96906187
#   -2580.42086734    351.32268971    454.51395293    475.42312758
#    -480.13531995    336.50999642  -2468.46680994]
#                            Coefficients
# --enable-debug            -16502.142704
# --enable-fast-install      -3115.314881
# --enable-geopoly           -2580.420867
# --enable-fts3              -2530.149226
# --with-tcl=/usr/lib64      -2468.466810
# --disable-largefile        -1936.864521
# --enable-fts4              -1795.998521
# --enable-releasemode       -1766.789062
# --disable-math             -1473.546207
# --enable-tempstore         -1166.063697
# --with-pic                  -480.135320
# --disable-tcl               -310.714738
# --disable-option-checking   -111.620964
# --enable-editline            169.894263
# --disable-libtool-lock       197.613275
# --enable-memsys5             274.586381
# --with-gnu-ld                336.509996
# --enable-rtree               351.322690
# --disable-load-extension     371.674667
# --enable-session             454.513953
# --enable-gcov                475.423128
# --enable-json1               510.258595
# --disable-threadsafe         742.991237
# --enable-memsys3             890.956588
# --disable-readline           910.500489
# --enable-static             1507.262841
# --enable-fts5               1689.280467
# --disable-amalgamation      2067.249524
# --enable-update-limit       3490.969062
# --enable-shared=no          3623.969059
# --enable-all                5965.541917
# Mean squared error: 30728151.39
# Coefficient of determination: 0.53
# MAPE 0.06418523198651971
# Mean squared error: 13337624.29
# Coefficient of determination: 0.80
# MAPE 0.0291336805039068
# Feature: 0, --disable-option-checking, Score: 0.00023
# Feature: 1, --disable-libtool-lock, Score: 0.00046
# Feature: 2, --disable-largefile, Score: 0.00000
# Feature: 3, --disable-threadsafe, Score: 0.00001
# Feature: 4, --disable-tcl, Score: 0.00015
# Feature: 5, --disable-readline, Score: 0.00000
# Feature: 6, --disable-amalgamation, Score: 0.00003
# Feature: 7, --disable-load-extension, Score: 0.00000
# Feature: 8, --disable-math, Score: 0.01750
# Feature: 9, --enable-shared=no, Score: 0.00002
# Feature: 10, --enable-static, Score: 0.00000
# Feature: 11, --enable-fast-install, Score: 0.00002
# Feature: 12, --enable-releasemode, Score: 0.00000
# Feature: 13, --enable-tempstore, Score: 0.00000
# Feature: 14, --enable-editline, Score: 0.00003
# Feature: 15, --enable-debug, Score: 0.84180
# Feature: 16, --enable-all, Score: 0.08132
# Feature: 17, --enable-memsys5, Score: 0.00001
# Feature: 18, --enable-memsys3, Score: 0.00000
# Feature: 19, --enable-fts3, Score: 0.00001
# Feature: 20, --enable-fts4, Score: 0.00080
# Feature: 21, --enable-fts5, Score: 0.05213
# Feature: 22, --enable-json1, Score: 0.00006
# Feature: 23, --enable-update-limit, Score: 0.00000
# Feature: 24, --enable-geopoly, Score: 0.00038
# Feature: 25, --enable-rtree, Score: 0.00000
# Feature: 26, --enable-session, Score: 0.00388
# Feature: 27, --enable-gcov, Score: 0.00000
# Feature: 28, --with-pic, Score: 0.00039
# Feature: 29, --with-gnu-ld, Score: 0.00007
# Feature: 30, --with-tcl=/usr/lib64, Score: 0.00068
# Mean squared error: 10430073.72
# Coefficient of determination: 0.84
# MAPE 0.02740270721218585
# Feature: 0, --disable-option-checking, Score: 0.00076
# Feature: 1, --disable-libtool-lock, Score: 0.00062
# Feature: 2, --disable-largefile, Score: 0.00343
# Feature: 3, --disable-threadsafe, Score: 0.00096
# Feature: 4, --disable-tcl, Score: 0.00027
# Feature: 5, --disable-readline, Score: 0.00039
# Feature: 6, --disable-amalgamation, Score: 0.00072
# Feature: 7, --disable-load-extension, Score: 0.00309
# Feature: 8, --disable-math, Score: 0.00410
# Feature: 9, --enable-shared=no, Score: 0.00093
# Feature: 10, --enable-static, Score: 0.00081
# Feature: 11, --enable-fast-install, Score: 0.00026
# Feature: 12, --enable-releasemode, Score: 0.00106
# Feature: 13, --enable-tempstore, Score: 0.00213
# Feature: 14, --enable-editline, Score: 0.00036
# Feature: 15, --enable-debug, Score: 0.84163
# Feature: 16, --enable-all, Score: 0.07782
# Feature: 17, --enable-memsys5, Score: 0.00158
# Feature: 18, --enable-memsys3, Score: 0.00088
# Feature: 19, --enable-fts3, Score: 0.00196
# Feature: 20, --enable-fts4, Score: 0.00078
# Feature: 21, --enable-fts5, Score: 0.04157
# Feature: 22, --enable-json1, Score: 0.00163
# Feature: 23, --enable-update-limit, Score: 0.00247
# Feature: 24, --enable-geopoly, Score: 0.00083
# Feature: 25, --enable-rtree, Score: 0.00071
# Feature: 26, --enable-session, Score: 0.00177
# Feature: 27, --enable-gcov, Score: 0.00037
# Feature: 28, --with-pic, Score: 0.00161
# Feature: 29, --with-gnu-ld, Score: 0.00022
# Feature: 30, --with-tcl=/usr/lib64, Score: 0.00429

# %%
odf['binary-size'].corr(odf['nr-of-gadgets'])
# Out:
# 0.9158147132466652
